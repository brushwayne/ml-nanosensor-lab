# %%
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import pandas as pd

df = read_csv("./database/run1.csv", delim_whitespace=False, header=None)

df = df.iloc[1:]

feature_names = ['Serial Number', 'Substrate Thickness', 'Patch Length', 'Patch Width', 'Frequency', 'Return Loss (s11)', 'Gain']

df.columns = feature_names

df = df.apply(pd.to_numeric)

y = df[['Substrate Thickness', 'Patch Length', 'Patch Width']]
x = df[['Frequency', 'Return Loss (s11)', 'Gain']]

print(df.head())

print(df.info())
# Out:
#    Serial Number  Substrate Thickness  Patch Length  Patch Width  Frequency  \
# 1              1                   80           136          180     0.6535
# 2              3                   82           136          180     0.6769
# 3              4                   83           136          180     0.6805
# 4              5                   84           136          180     0.6841
# 5              6                   85           136          180     0.6841
#
#    Return Loss (s11)    Gain
# 1            -23.114  9.9730
# 2            -32.885  9.2812
# 3            -56.370  9.1623
# 4            -47.889  9.0913
# 5            -38.306  9.0199
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 1 to 998
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Serial Number        998 non-null    int64
#  1   Substrate Thickness  998 non-null    int64
#  2   Patch Length         998 non-null    int64
#  3   Patch Width          998 non-null    int64
#  4   Frequency            998 non-null    float64
#  5   Return Loss (s11)    998 non-null    float64
#  6   Gain                 998 non-null    float64
# dtypes: float64(3), int64(4)
# memory usage: 54.7 KB
# None

# %%
import random

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = random.randint(256, 999))

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)

model = Sequential()
model.add(Dense(128, input_dim=3, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
#Output layer
model.add(Dense(3, activation='linear'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
model.summary()

history = model.fit(X_train_scaled, y_train, validation_split=0.20, epochs = 1000)

from matplotlib import pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['mae']
val_acc = history.history['val_mae']
plt.plot(epochs, acc, 'y', label='Training MAE')
plt.plot(epochs, val_acc, 'r', label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


predictions = model.predict(X_test_scaled[:5])
print("Predicted values are: ", predictions)
print("Real values are: ", y_test[:5])

mse_neural, mae_neural = model.evaluate(X_test_scaled, y_test)
print('Mean squared error from neural net: ', mse_neural)
print('Mean absolute error from neural net: ', mae_neural)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 128)               512
#
#  dense_21 (Dense)            (None, 128)               16512
#
#  dense_22 (Dense)            (None, 128)               16512
#
#  dense_23 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 33,923
# Trainable params: 33,923
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 20/20 [==============================] - 1s 8ms/step - loss: 20042.7109 - mae: 135.5471 - val_loss: 19571.1777 - val_mae: 133.9556
# Epoch 2/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 17971.7207 - mae: 127.8052 - val_loss: 15518.4160 - val_mae: 118.1485
# Epoch 3/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 10370.4541 - mae: 91.2038 - val_loss: 5174.0425 - val_mae: 60.0758
# Epoch 4/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3437.2998 - mae: 46.7404 - val_loss: 1823.0729 - val_mae: 35.1046
# Epoch 5/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 1792.5648 - mae: 32.8208 - val_loss: 1145.0623 - val_mae: 28.8492
# Epoch 6/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 1257.4246 - mae: 26.3843 - val_loss: 655.7722 - val_mae: 21.6105
# Epoch 7/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 914.6896 - mae: 22.0370 - val_loss: 451.3102 - val_mae: 17.6832
# Epoch 8/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 704.8019 - mae: 17.7814 - val_loss: 377.9331 - val_mae: 16.3781
# Epoch 9/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 538.6161 - mae: 16.2576 - val_loss: 220.0939 - val_mae: 11.7573
# Epoch 10/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 416.6081 - mae: 13.9772 - val_loss: 180.4371 - val_mae: 10.9236
# Epoch 11/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 311.2560 - mae: 11.5462 - val_loss: 139.8647 - val_mae: 9.6913
# Epoch 12/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 252.2544 - mae: 10.3179 - val_loss: 110.0166 - val_mae: 8.6504
# Epoch 13/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 195.7360 - mae: 8.8657 - val_loss: 85.5934 - val_mae: 7.4211
# Epoch 14/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 157.1292 - mae: 8.1684 - val_loss: 66.3775 - val_mae: 6.2626
# Epoch 15/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 128.5267 - mae: 7.3899 - val_loss: 55.2547 - val_mae: 5.7298
# Epoch 16/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 103.5974 - mae: 6.8015 - val_loss: 46.0084 - val_mae: 5.3366
# Epoch 17/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 83.6867 - mae: 5.7613 - val_loss: 42.0455 - val_mae: 5.2350
# Epoch 18/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 68.2140 - mae: 5.2913 - val_loss: 29.2584 - val_mae: 4.2600
# Epoch 19/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 54.4799 - mae: 4.8384 - val_loss: 25.9776 - val_mae: 3.9463
# Epoch 20/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 44.8356 - mae: 4.4779 - val_loss: 22.2048 - val_mae: 3.6826
# Epoch 21/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 37.5287 - mae: 4.0490 - val_loss: 18.7465 - val_mae: 3.4096
# Epoch 22/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 31.4229 - mae: 3.7758 - val_loss: 16.5334 - val_mae: 3.0897
# Epoch 23/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 25.4566 - mae: 3.4516 - val_loss: 13.4233 - val_mae: 2.8601
# Epoch 24/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 21.0514 - mae: 3.1119 - val_loss: 11.9101 - val_mae: 2.6591
# Epoch 25/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 17.7474 - mae: 2.9141 - val_loss: 10.5196 - val_mae: 2.5076
# Epoch 26/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 15.3361 - mae: 2.7394 - val_loss: 9.6746 - val_mae: 2.4016
# Epoch 27/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 13.5745 - mae: 2.6323 - val_loss: 9.4852 - val_mae: 2.3570
# Epoch 28/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 12.4160 - mae: 2.5609 - val_loss: 9.2635 - val_mae: 2.3270
# Epoch 29/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 11.4714 - mae: 2.4695 - val_loss: 8.3224 - val_mae: 2.2163
# Epoch 30/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 10.6114 - mae: 2.3968 - val_loss: 8.2198 - val_mae: 2.1835
# Epoch 31/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 10.0915 - mae: 2.3368 - val_loss: 7.9696 - val_mae: 2.1772
# Epoch 32/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 9.6684 - mae: 2.3090 - val_loss: 7.7842 - val_mae: 2.1595
# Epoch 33/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 9.2887 - mae: 2.2555 - val_loss: 7.5505 - val_mae: 2.1076
# Epoch 34/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 8.9992 - mae: 2.2111 - val_loss: 7.5875 - val_mae: 2.1200
# Epoch 35/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 8.7901 - mae: 2.2096 - val_loss: 7.6000 - val_mae: 2.1027
# Epoch 36/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 8.4556 - mae: 2.1644 - val_loss: 7.0740 - val_mae: 2.0535
# Epoch 37/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 8.2088 - mae: 2.1218 - val_loss: 6.9432 - val_mae: 2.0363
# Epoch 38/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 7.9884 - mae: 2.1115 - val_loss: 6.8114 - val_mae: 2.0259
# Epoch 39/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 7.8743 - mae: 2.1143 - val_loss: 6.7089 - val_mae: 2.0035
# Epoch 40/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 7.7541 - mae: 2.0664 - val_loss: 6.6380 - val_mae: 1.9938
# Epoch 41/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 7.5089 - mae: 2.0589 - val_loss: 6.5490 - val_mae: 1.9790
# Epoch 42/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 7.4440 - mae: 2.0432 - val_loss: 6.4774 - val_mae: 1.9942
# Epoch 43/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 7.2194 - mae: 2.0158 - val_loss: 6.5221 - val_mae: 1.9738
# Epoch 44/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 7.0985 - mae: 2.0009 - val_loss: 6.2183 - val_mae: 1.9541
# Epoch 45/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 6.9882 - mae: 1.9859 - val_loss: 6.1213 - val_mae: 1.9262
# Epoch 46/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.8024 - mae: 1.9757 - val_loss: 6.0721 - val_mae: 1.9075
# Epoch 47/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 6.7728 - mae: 1.9576 - val_loss: 6.0197 - val_mae: 1.9187
# Epoch 48/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.6810 - mae: 1.9424 - val_loss: 5.9654 - val_mae: 1.9110
# Epoch 49/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 6.6023 - mae: 1.9468 - val_loss: 5.9497 - val_mae: 1.9007
# Epoch 50/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.5456 - mae: 1.9378 - val_loss: 6.0058 - val_mae: 1.9057
# Epoch 51/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 6.4727 - mae: 1.9391 - val_loss: 6.1457 - val_mae: 1.9171
# Epoch 52/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.4476 - mae: 1.9124 - val_loss: 5.7843 - val_mae: 1.9054
# Epoch 53/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 6.3305 - mae: 1.9151 - val_loss: 6.1709 - val_mae: 1.9397
# Epoch 54/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.3577 - mae: 1.9322 - val_loss: 6.6598 - val_mae: 2.0055
# Epoch 55/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 6.3520 - mae: 1.9281 - val_loss: 5.6459 - val_mae: 1.8524
# Epoch 56/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.1359 - mae: 1.8806 - val_loss: 5.7977 - val_mae: 1.8609
# Epoch 57/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 6.1058 - mae: 1.8867 - val_loss: 5.5932 - val_mae: 1.8385
# Epoch 58/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.9398 - mae: 1.8629 - val_loss: 5.3319 - val_mae: 1.7983
# Epoch 59/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 5.8627 - mae: 1.8464 - val_loss: 5.4153 - val_mae: 1.8304
# Epoch 60/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.7343 - mae: 1.8278 - val_loss: 5.2864 - val_mae: 1.7933
# Epoch 61/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 5.7092 - mae: 1.8448 - val_loss: 5.3193 - val_mae: 1.7975
# Epoch 62/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 5.6140 - mae: 1.8312 - val_loss: 5.4161 - val_mae: 1.8299
# Epoch 63/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 5.5521 - mae: 1.8069 - val_loss: 5.1044 - val_mae: 1.7784
# Epoch 64/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 5.4083 - mae: 1.7977 - val_loss: 5.0075 - val_mae: 1.7531
# Epoch 65/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 5.4251 - mae: 1.7940 - val_loss: 5.2045 - val_mae: 1.7742
# Epoch 66/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.3683 - mae: 1.7848 - val_loss: 5.0240 - val_mae: 1.7589
# Epoch 67/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.3473 - mae: 1.7784 - val_loss: 5.0152 - val_mae: 1.7442
# Epoch 68/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.2918 - mae: 1.7723 - val_loss: 5.0225 - val_mae: 1.7594
# Epoch 69/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.1895 - mae: 1.7526 - val_loss: 4.8047 - val_mae: 1.7146
# Epoch 70/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.1962 - mae: 1.7572 - val_loss: 5.0907 - val_mae: 1.7394
# Epoch 71/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.1221 - mae: 1.7437 - val_loss: 4.7404 - val_mae: 1.7077
# Epoch 72/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.0014 - mae: 1.7263 - val_loss: 4.7384 - val_mae: 1.7071
# Epoch 73/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.0588 - mae: 1.7288 - val_loss: 4.7729 - val_mae: 1.7161
# Epoch 74/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.9421 - mae: 1.7029 - val_loss: 4.8225 - val_mae: 1.7388
# Epoch 75/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.0329 - mae: 1.7335 - val_loss: 5.0134 - val_mae: 1.7554
# Epoch 76/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.8858 - mae: 1.7035 - val_loss: 4.6313 - val_mae: 1.7038
# Epoch 77/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.8845 - mae: 1.6931 - val_loss: 4.6285 - val_mae: 1.6837
# Epoch 78/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.7903 - mae: 1.6875 - val_loss: 4.9609 - val_mae: 1.7283
# Epoch 79/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.7803 - mae: 1.6778 - val_loss: 4.5846 - val_mae: 1.6983
# Epoch 80/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.8703 - mae: 1.6974 - val_loss: 4.4609 - val_mae: 1.6714
# Epoch 81/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.8677 - mae: 1.7153 - val_loss: 4.9070 - val_mae: 1.7075
# Epoch 82/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.7411 - mae: 1.6832 - val_loss: 4.5430 - val_mae: 1.6557
# Epoch 83/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.5972 - mae: 1.6484 - val_loss: 4.3998 - val_mae: 1.6438
# Epoch 84/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.7694 - mae: 1.6740 - val_loss: 4.4145 - val_mae: 1.6406
# Epoch 85/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.6428 - mae: 1.6415 - val_loss: 4.4962 - val_mae: 1.6650
# Epoch 86/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.6994 - mae: 1.6684 - val_loss: 4.9991 - val_mae: 1.7021
# Epoch 87/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.5381 - mae: 1.6217 - val_loss: 4.3076 - val_mae: 1.6387
# Epoch 88/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.6295 - mae: 1.6467 - val_loss: 4.8274 - val_mae: 1.6887
# Epoch 89/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.6092 - mae: 1.6489 - val_loss: 4.3742 - val_mae: 1.6164
# Epoch 90/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.4618 - mae: 1.6200 - val_loss: 4.2887 - val_mae: 1.6245
# Epoch 91/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.3676 - mae: 1.6111 - val_loss: 4.4205 - val_mae: 1.6195
# Epoch 92/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.3032 - mae: 1.6011 - val_loss: 4.3503 - val_mae: 1.6528
# Epoch 93/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.3069 - mae: 1.5831 - val_loss: 4.2173 - val_mae: 1.6111
# Epoch 94/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.2709 - mae: 1.5837 - val_loss: 4.2609 - val_mae: 1.6014
# Epoch 95/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.2466 - mae: 1.5847 - val_loss: 4.1203 - val_mae: 1.5772
# Epoch 96/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.1985 - mae: 1.5714 - val_loss: 4.1675 - val_mae: 1.5724
# Epoch 97/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.1865 - mae: 1.5676 - val_loss: 4.2438 - val_mae: 1.6143
# Epoch 98/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.2248 - mae: 1.5596 - val_loss: 4.3448 - val_mae: 1.6267
# Epoch 99/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.0893 - mae: 1.5338 - val_loss: 4.0529 - val_mae: 1.5616
# Epoch 100/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.0867 - mae: 1.5458 - val_loss: 4.1289 - val_mae: 1.5780
# Epoch 101/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.0920 - mae: 1.5438 - val_loss: 4.0764 - val_mae: 1.5628
# Epoch 102/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.1649 - mae: 1.5568 - val_loss: 4.0964 - val_mae: 1.5789
# Epoch 103/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.1560 - mae: 1.5402 - val_loss: 3.9524 - val_mae: 1.5512
# Epoch 104/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9353 - mae: 1.5120 - val_loss: 3.9873 - val_mae: 1.5424
# Epoch 105/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.9204 - mae: 1.5154 - val_loss: 4.1103 - val_mae: 1.5529
# Epoch 106/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9678 - mae: 1.5002 - val_loss: 3.9882 - val_mae: 1.5778
# Epoch 107/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.1006 - mae: 1.5388 - val_loss: 3.9719 - val_mae: 1.5566
# Epoch 108/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9883 - mae: 1.5137 - val_loss: 3.8766 - val_mae: 1.5688
# Epoch 109/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.9548 - mae: 1.5196 - val_loss: 3.9844 - val_mae: 1.5354
# Epoch 110/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.9084 - mae: 1.5002 - val_loss: 3.8676 - val_mae: 1.5231
# Epoch 111/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.0708 - mae: 1.5244 - val_loss: 4.2113 - val_mae: 1.6063
# Epoch 112/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8964 - mae: 1.4988 - val_loss: 4.1234 - val_mae: 1.5434
# Epoch 113/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8468 - mae: 1.4798 - val_loss: 3.8232 - val_mae: 1.5079
# Epoch 114/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8216 - mae: 1.4706 - val_loss: 3.8376 - val_mae: 1.5131
# Epoch 115/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8881 - mae: 1.4893 - val_loss: 3.8203 - val_mae: 1.5180
# Epoch 116/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8028 - mae: 1.4693 - val_loss: 3.9187 - val_mae: 1.5458
# Epoch 117/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.7198 - mae: 1.4611 - val_loss: 3.8364 - val_mae: 1.5210
# Epoch 118/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.7254 - mae: 1.4606 - val_loss: 3.9333 - val_mae: 1.5128
# Epoch 119/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6960 - mae: 1.4500 - val_loss: 3.7801 - val_mae: 1.5091
# Epoch 120/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.7220 - mae: 1.4581 - val_loss: 3.8777 - val_mae: 1.5385
# Epoch 121/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6885 - mae: 1.4610 - val_loss: 4.0694 - val_mae: 1.5414
# Epoch 122/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6983 - mae: 1.4444 - val_loss: 3.7787 - val_mae: 1.4900
# Epoch 123/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6919 - mae: 1.4472 - val_loss: 3.7894 - val_mae: 1.5221
# Epoch 124/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6312 - mae: 1.4464 - val_loss: 3.8392 - val_mae: 1.5003
# Epoch 125/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6222 - mae: 1.4341 - val_loss: 3.8241 - val_mae: 1.5022
# Epoch 126/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6156 - mae: 1.4287 - val_loss: 3.6934 - val_mae: 1.4966
# Epoch 127/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5983 - mae: 1.4328 - val_loss: 3.6527 - val_mae: 1.4887
# Epoch 128/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.7901 - mae: 1.4549 - val_loss: 3.6760 - val_mae: 1.5084
# Epoch 129/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8329 - mae: 1.4932 - val_loss: 3.9365 - val_mae: 1.5602
# Epoch 130/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9901 - mae: 1.5027 - val_loss: 3.9531 - val_mae: 1.5454
# Epoch 131/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6644 - mae: 1.4541 - val_loss: 3.6063 - val_mae: 1.4782
# Epoch 132/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6391 - mae: 1.4381 - val_loss: 3.8333 - val_mae: 1.5314
# Epoch 133/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.7417 - mae: 1.4528 - val_loss: 4.1333 - val_mae: 1.5699
# Epoch 134/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.7644 - mae: 1.4646 - val_loss: 3.9012 - val_mae: 1.5293
# Epoch 135/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6871 - mae: 1.4475 - val_loss: 3.6226 - val_mae: 1.4983
# Epoch 136/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5124 - mae: 1.4130 - val_loss: 3.6609 - val_mae: 1.5038
# Epoch 137/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5956 - mae: 1.4302 - val_loss: 4.1999 - val_mae: 1.5784
# Epoch 138/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.7637 - mae: 1.4697 - val_loss: 3.6733 - val_mae: 1.4879
# Epoch 139/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8032 - mae: 1.4850 - val_loss: 3.5755 - val_mae: 1.4538
# Epoch 140/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4673 - mae: 1.4037 - val_loss: 3.5984 - val_mae: 1.4559
# Epoch 141/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4731 - mae: 1.4047 - val_loss: 3.6399 - val_mae: 1.4913
# Epoch 142/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6427 - mae: 1.4438 - val_loss: 3.6869 - val_mae: 1.4955
# Epoch 143/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5781 - mae: 1.4283 - val_loss: 3.6784 - val_mae: 1.4980
# Epoch 144/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.5433 - mae: 1.4172 - val_loss: 3.6091 - val_mae: 1.4546
# Epoch 145/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5073 - mae: 1.4082 - val_loss: 3.6586 - val_mae: 1.4583
# Epoch 146/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5621 - mae: 1.4174 - val_loss: 3.5519 - val_mae: 1.4447
# Epoch 147/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6688 - mae: 1.4524 - val_loss: 3.7536 - val_mae: 1.5320
# Epoch 148/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5228 - mae: 1.4277 - val_loss: 4.0383 - val_mae: 1.5469
# Epoch 149/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5265 - mae: 1.4199 - val_loss: 4.0454 - val_mae: 1.5298
# Epoch 150/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.0686 - mae: 1.4929 - val_loss: 7.3424 - val_mae: 1.7955
# Epoch 151/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 8.4157 - mae: 1.9594 - val_loss: 6.3867 - val_mae: 2.0475
# Epoch 152/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.6713 - mae: 1.6194 - val_loss: 3.6018 - val_mae: 1.5133
# Epoch 153/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4880 - mae: 1.4132 - val_loss: 3.4476 - val_mae: 1.4439
# Epoch 154/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5409 - mae: 1.4465 - val_loss: 3.6093 - val_mae: 1.4857
# Epoch 155/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5557 - mae: 1.4269 - val_loss: 3.5060 - val_mae: 1.4523
# Epoch 156/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5122 - mae: 1.4158 - val_loss: 3.6171 - val_mae: 1.4501
# Epoch 157/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4236 - mae: 1.4037 - val_loss: 3.6756 - val_mae: 1.4650
# Epoch 158/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3894 - mae: 1.3819 - val_loss: 3.7056 - val_mae: 1.4872
# Epoch 159/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2926 - mae: 1.3725 - val_loss: 3.5122 - val_mae: 1.4957
# Epoch 160/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3316 - mae: 1.3784 - val_loss: 3.4683 - val_mae: 1.4471
# Epoch 161/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3949 - mae: 1.3955 - val_loss: 3.8166 - val_mae: 1.4949
# Epoch 162/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2918 - mae: 1.3712 - val_loss: 3.5926 - val_mae: 1.4489
# Epoch 163/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3152 - mae: 1.3760 - val_loss: 3.4688 - val_mae: 1.4250
# Epoch 164/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3899 - mae: 1.3912 - val_loss: 3.6635 - val_mae: 1.4570
# Epoch 165/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3860 - mae: 1.3838 - val_loss: 3.5405 - val_mae: 1.4701
# Epoch 166/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4427 - mae: 1.4193 - val_loss: 3.6329 - val_mae: 1.4595
# Epoch 167/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3309 - mae: 1.3774 - val_loss: 3.4517 - val_mae: 1.4208
# Epoch 168/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2955 - mae: 1.3732 - val_loss: 3.4839 - val_mae: 1.4882
# Epoch 169/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3972 - mae: 1.4015 - val_loss: 3.5968 - val_mae: 1.4579
# Epoch 170/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4707 - mae: 1.3921 - val_loss: 3.9668 - val_mae: 1.5405
# Epoch 171/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4049 - mae: 1.3895 - val_loss: 3.5393 - val_mae: 1.4515
# Epoch 172/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2601 - mae: 1.3569 - val_loss: 3.6500 - val_mae: 1.4647
# Epoch 173/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4046 - mae: 1.3927 - val_loss: 3.6189 - val_mae: 1.5100
# Epoch 174/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3707 - mae: 1.3903 - val_loss: 3.5822 - val_mae: 1.4305
# Epoch 175/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2709 - mae: 1.3587 - val_loss: 3.6117 - val_mae: 1.4647
# Epoch 176/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3755 - mae: 1.3895 - val_loss: 3.5908 - val_mae: 1.4412
# Epoch 177/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3725 - mae: 1.3904 - val_loss: 3.6980 - val_mae: 1.4832
# Epoch 178/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4850 - mae: 1.4213 - val_loss: 3.5416 - val_mae: 1.4542
# Epoch 179/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4493 - mae: 1.3962 - val_loss: 3.6087 - val_mae: 1.4516
# Epoch 180/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4981 - mae: 1.4198 - val_loss: 3.5298 - val_mae: 1.4375
# Epoch 181/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3252 - mae: 1.3734 - val_loss: 3.5323 - val_mae: 1.4464
# Epoch 182/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3162 - mae: 1.3808 - val_loss: 3.5218 - val_mae: 1.4412
# Epoch 183/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4387 - mae: 1.4063 - val_loss: 3.3947 - val_mae: 1.4392
# Epoch 184/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3474 - mae: 1.3894 - val_loss: 3.4228 - val_mae: 1.4290
# Epoch 185/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2629 - mae: 1.3551 - val_loss: 3.4700 - val_mae: 1.4281
# Epoch 186/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2371 - mae: 1.3612 - val_loss: 3.3314 - val_mae: 1.4129
# Epoch 187/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2735 - mae: 1.3559 - val_loss: 3.4376 - val_mae: 1.4095
# Epoch 188/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3783 - mae: 1.4001 - val_loss: 3.6073 - val_mae: 1.4794
# Epoch 189/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.3197 - mae: 1.3712 - val_loss: 3.8369 - val_mae: 1.5088
# Epoch 190/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4617 - mae: 1.3969 - val_loss: 3.7199 - val_mae: 1.4686
# Epoch 191/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3338 - mae: 1.3796 - val_loss: 3.4052 - val_mae: 1.4269
# Epoch 192/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4504 - mae: 1.4121 - val_loss: 3.7763 - val_mae: 1.4790
# Epoch 193/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2549 - mae: 1.3622 - val_loss: 3.3536 - val_mae: 1.4158
# Epoch 194/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3865 - mae: 1.3965 - val_loss: 3.5507 - val_mae: 1.4597
# Epoch 195/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2670 - mae: 1.3667 - val_loss: 3.5430 - val_mae: 1.4344
# Epoch 196/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2944 - mae: 1.3655 - val_loss: 3.3805 - val_mae: 1.4163
# Epoch 197/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2895 - mae: 1.3703 - val_loss: 3.4549 - val_mae: 1.4328
# Epoch 198/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3839 - mae: 1.3914 - val_loss: 3.5433 - val_mae: 1.4458
# Epoch 199/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1945 - mae: 1.3461 - val_loss: 3.7005 - val_mae: 1.4778
# Epoch 200/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2996 - mae: 1.3610 - val_loss: 3.4060 - val_mae: 1.4287
# Epoch 201/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2712 - mae: 1.3606 - val_loss: 3.3989 - val_mae: 1.4274
# Epoch 202/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2351 - mae: 1.3641 - val_loss: 3.4076 - val_mae: 1.4145
# Epoch 203/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1900 - mae: 1.3579 - val_loss: 3.5461 - val_mae: 1.4651
# Epoch 204/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3825 - mae: 1.3916 - val_loss: 3.7336 - val_mae: 1.4692
# Epoch 205/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4157 - mae: 1.3892 - val_loss: 3.9902 - val_mae: 1.5830
# Epoch 206/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2200 - mae: 1.3505 - val_loss: 3.3748 - val_mae: 1.4066
# Epoch 207/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2240 - mae: 1.3553 - val_loss: 3.6014 - val_mae: 1.4512
# Epoch 208/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2700 - mae: 1.3601 - val_loss: 3.4643 - val_mae: 1.4491
# Epoch 209/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3321 - mae: 1.3847 - val_loss: 3.6515 - val_mae: 1.4746
# Epoch 210/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4835 - mae: 1.3925 - val_loss: 3.5419 - val_mae: 1.4282
# Epoch 211/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5068 - mae: 1.4063 - val_loss: 3.6295 - val_mae: 1.4735
# Epoch 212/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3535 - mae: 1.3744 - val_loss: 3.5962 - val_mae: 1.4648
# Epoch 213/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2889 - mae: 1.3786 - val_loss: 3.3405 - val_mae: 1.3937
# Epoch 214/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5491 - mae: 1.4413 - val_loss: 3.5293 - val_mae: 1.4432
# Epoch 215/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4081 - mae: 1.3910 - val_loss: 3.3102 - val_mae: 1.4126
# Epoch 216/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3973 - mae: 1.3909 - val_loss: 3.3944 - val_mae: 1.3999
# Epoch 217/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2068 - mae: 1.3496 - val_loss: 3.4394 - val_mae: 1.4234
# Epoch 218/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4204 - mae: 1.3911 - val_loss: 3.9778 - val_mae: 1.5942
# Epoch 219/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8522 - mae: 1.4706 - val_loss: 3.8774 - val_mae: 1.5628
# Epoch 220/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.7810 - mae: 1.4986 - val_loss: 3.3969 - val_mae: 1.3995
# Epoch 221/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5536 - mae: 1.4463 - val_loss: 4.0577 - val_mae: 1.5582
# Epoch 222/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4033 - mae: 1.4050 - val_loss: 3.8416 - val_mae: 1.5650
# Epoch 223/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6316 - mae: 1.4404 - val_loss: 3.6082 - val_mae: 1.4634
# Epoch 224/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4458 - mae: 1.4015 - val_loss: 4.0329 - val_mae: 1.5346
# Epoch 225/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3421 - mae: 1.3797 - val_loss: 3.3930 - val_mae: 1.4347
# Epoch 226/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.2502 - mae: 1.3695 - val_loss: 3.7061 - val_mae: 1.5060
# Epoch 227/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6941 - mae: 1.4406 - val_loss: 3.4430 - val_mae: 1.4112
# Epoch 228/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2661 - mae: 1.3534 - val_loss: 3.8077 - val_mae: 1.5301
# Epoch 229/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2424 - mae: 1.3631 - val_loss: 3.3869 - val_mae: 1.4124
# Epoch 230/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6009 - mae: 1.4174 - val_loss: 4.1002 - val_mae: 1.5044
# Epoch 231/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9044 - mae: 1.5053 - val_loss: 3.5457 - val_mae: 1.4235
# Epoch 232/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5560 - mae: 1.4153 - val_loss: 3.3823 - val_mae: 1.4417
# Epoch 233/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.7532 - mae: 1.4391 - val_loss: 4.3468 - val_mae: 1.7245
# Epoch 234/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9634 - mae: 1.4981 - val_loss: 3.9691 - val_mae: 1.5531
# Epoch 235/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6989 - mae: 1.4313 - val_loss: 4.1018 - val_mae: 1.5629
# Epoch 236/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5495 - mae: 1.4432 - val_loss: 3.5391 - val_mae: 1.4762
# Epoch 237/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1621 - mae: 1.3397 - val_loss: 3.2777 - val_mae: 1.4018
# Epoch 238/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2032 - mae: 1.3568 - val_loss: 3.4968 - val_mae: 1.4095
# Epoch 239/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2297 - mae: 1.3586 - val_loss: 3.4740 - val_mae: 1.4316
# Epoch 240/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3233 - mae: 1.3649 - val_loss: 3.3616 - val_mae: 1.4609
# Epoch 241/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2199 - mae: 1.3414 - val_loss: 3.3976 - val_mae: 1.3893
# Epoch 242/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1514 - mae: 1.3314 - val_loss: 3.3347 - val_mae: 1.4113
# Epoch 243/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2432 - mae: 1.3501 - val_loss: 3.6515 - val_mae: 1.4263
# Epoch 244/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1498 - mae: 1.3335 - val_loss: 3.8551 - val_mae: 1.5700
# Epoch 245/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3481 - mae: 1.3978 - val_loss: 3.4068 - val_mae: 1.3878
# Epoch 246/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1450 - mae: 1.3407 - val_loss: 3.7255 - val_mae: 1.4779
# Epoch 247/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4382 - mae: 1.3918 - val_loss: 3.3790 - val_mae: 1.4200
# Epoch 248/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2326 - mae: 1.3479 - val_loss: 3.6080 - val_mae: 1.4886
# Epoch 249/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2046 - mae: 1.3565 - val_loss: 3.4826 - val_mae: 1.4683
# Epoch 250/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3119 - mae: 1.3732 - val_loss: 3.9088 - val_mae: 1.4992
# Epoch 251/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5595 - mae: 1.4319 - val_loss: 4.6009 - val_mae: 1.6544
# Epoch 252/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4513 - mae: 1.4134 - val_loss: 3.5711 - val_mae: 1.4770
# Epoch 253/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3901 - mae: 1.3866 - val_loss: 3.2764 - val_mae: 1.4109
# Epoch 254/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2060 - mae: 1.3542 - val_loss: 3.4269 - val_mae: 1.4199
# Epoch 255/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1395 - mae: 1.3333 - val_loss: 3.4260 - val_mae: 1.4148
# Epoch 256/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4997 - mae: 1.4184 - val_loss: 3.5226 - val_mae: 1.4267
# Epoch 257/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4765 - mae: 1.4123 - val_loss: 3.3427 - val_mae: 1.4176
# Epoch 258/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1037 - mae: 1.3273 - val_loss: 3.3784 - val_mae: 1.4082
# Epoch 259/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2327 - mae: 1.3675 - val_loss: 3.4555 - val_mae: 1.4248
# Epoch 260/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.2332 - mae: 1.3635 - val_loss: 3.2452 - val_mae: 1.4108
# Epoch 261/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2520 - mae: 1.3654 - val_loss: 3.4835 - val_mae: 1.3969
# Epoch 262/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3218 - mae: 1.3759 - val_loss: 3.9774 - val_mae: 1.5142
# Epoch 263/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3910 - mae: 1.3942 - val_loss: 3.6029 - val_mae: 1.5056
# Epoch 264/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4520 - mae: 1.3939 - val_loss: 3.3943 - val_mae: 1.4046
# Epoch 265/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1568 - mae: 1.3358 - val_loss: 3.4304 - val_mae: 1.4659
# Epoch 266/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1360 - mae: 1.3490 - val_loss: 3.6943 - val_mae: 1.4575
# Epoch 267/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2654 - mae: 1.3535 - val_loss: 3.7140 - val_mae: 1.5015
# Epoch 268/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6444 - mae: 1.4357 - val_loss: 3.4493 - val_mae: 1.4282
# Epoch 269/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.0744 - mae: 1.6462 - val_loss: 4.5752 - val_mae: 1.6393
# Epoch 270/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 5.1173 - mae: 1.7278 - val_loss: 4.3571 - val_mae: 1.6572
# Epoch 271/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8676 - mae: 1.4940 - val_loss: 3.6932 - val_mae: 1.4497
# Epoch 272/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5744 - mae: 1.4434 - val_loss: 3.4365 - val_mae: 1.4540
# Epoch 273/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1784 - mae: 1.3614 - val_loss: 3.4049 - val_mae: 1.4107
# Epoch 274/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4611 - mae: 1.4086 - val_loss: 3.7403 - val_mae: 1.4909
# Epoch 275/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6943 - mae: 1.4582 - val_loss: 3.5189 - val_mae: 1.4311
# Epoch 276/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1013 - mae: 1.3170 - val_loss: 3.4004 - val_mae: 1.4120
# Epoch 277/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2024 - mae: 1.3451 - val_loss: 3.5407 - val_mae: 1.4884
# Epoch 278/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3770 - mae: 1.3909 - val_loss: 3.5645 - val_mae: 1.4441
# Epoch 279/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8846 - mae: 1.4727 - val_loss: 3.9655 - val_mae: 1.5146
# Epoch 280/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6272 - mae: 1.4681 - val_loss: 3.4448 - val_mae: 1.4002
# Epoch 281/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4763 - mae: 1.3982 - val_loss: 3.7703 - val_mae: 1.5015
# Epoch 282/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.7733 - mae: 1.4673 - val_loss: 3.7511 - val_mae: 1.4951
# Epoch 283/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6461 - mae: 1.4465 - val_loss: 4.9552 - val_mae: 1.7984
# Epoch 284/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8099 - mae: 1.4614 - val_loss: 3.7927 - val_mae: 1.4656
# Epoch 285/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.7421 - mae: 1.4664 - val_loss: 3.7248 - val_mae: 1.4895
# Epoch 286/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4755 - mae: 1.3971 - val_loss: 3.4119 - val_mae: 1.4261
# Epoch 287/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1798 - mae: 1.3455 - val_loss: 3.2949 - val_mae: 1.3968
# Epoch 288/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0792 - mae: 1.3180 - val_loss: 3.2341 - val_mae: 1.3741
# Epoch 289/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0771 - mae: 1.3176 - val_loss: 3.1525 - val_mae: 1.3670
# Epoch 290/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0374 - mae: 1.3105 - val_loss: 3.2928 - val_mae: 1.3836
# Epoch 291/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1045 - mae: 1.3269 - val_loss: 3.4326 - val_mae: 1.4313
# Epoch 292/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.1242 - mae: 1.3368 - val_loss: 3.5669 - val_mae: 1.4773
# Epoch 293/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6322 - mae: 1.4189 - val_loss: 5.1159 - val_mae: 1.6640
# Epoch 294/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.0197 - mae: 1.5099 - val_loss: 3.3160 - val_mae: 1.3928
# Epoch 295/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3713 - mae: 1.4061 - val_loss: 3.8389 - val_mae: 1.5161
# Epoch 296/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6393 - mae: 1.4185 - val_loss: 3.2141 - val_mae: 1.3578
# Epoch 297/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1706 - mae: 1.3356 - val_loss: 3.1342 - val_mae: 1.3662
# Epoch 298/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2509 - mae: 1.3610 - val_loss: 3.3396 - val_mae: 1.3993
# Epoch 299/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3211 - mae: 1.3729 - val_loss: 3.7198 - val_mae: 1.5150
# Epoch 300/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1612 - mae: 1.3344 - val_loss: 3.3162 - val_mae: 1.4164
# Epoch 301/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3074 - mae: 1.3720 - val_loss: 4.3714 - val_mae: 1.6622
# Epoch 302/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.1383 - mae: 1.5404 - val_loss: 3.7256 - val_mae: 1.4838
# Epoch 303/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6073 - mae: 1.4366 - val_loss: 3.7598 - val_mae: 1.4803
# Epoch 304/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8443 - mae: 1.4583 - val_loss: 3.6899 - val_mae: 1.4982
# Epoch 305/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.9142 - mae: 1.6441 - val_loss: 3.8767 - val_mae: 1.5211
# Epoch 306/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.9046 - mae: 1.4978 - val_loss: 3.8527 - val_mae: 1.5016
# Epoch 307/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.3674 - mae: 1.5501 - val_loss: 3.9805 - val_mae: 1.4823
# Epoch 308/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.7541 - mae: 1.6050 - val_loss: 4.3554 - val_mae: 1.5712
# Epoch 309/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.3954 - mae: 1.6013 - val_loss: 3.6884 - val_mae: 1.4818
# Epoch 310/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.6751 - mae: 1.5691 - val_loss: 3.5563 - val_mae: 1.5020
# Epoch 311/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8875 - mae: 1.4803 - val_loss: 4.8100 - val_mae: 1.7446
# Epoch 312/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 4.1578 - mae: 1.5390 - val_loss: 4.1908 - val_mae: 1.5543
# Epoch 313/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4446 - mae: 1.3887 - val_loss: 3.1948 - val_mae: 1.3702
# Epoch 314/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2742 - mae: 1.3641 - val_loss: 3.7249 - val_mae: 1.4738
# Epoch 315/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.8788 - mae: 1.4822 - val_loss: 4.5308 - val_mae: 1.6105
# Epoch 316/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4480 - mae: 1.4191 - val_loss: 3.3139 - val_mae: 1.3813
# Epoch 317/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2670 - mae: 1.3620 - val_loss: 3.3095 - val_mae: 1.4027
# Epoch 318/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0261 - mae: 1.3229 - val_loss: 3.3331 - val_mae: 1.3710
# Epoch 319/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0658 - mae: 1.3291 - val_loss: 3.5419 - val_mae: 1.4244
# Epoch 320/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0126 - mae: 1.3035 - val_loss: 3.4015 - val_mae: 1.4247
# Epoch 321/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1481 - mae: 1.3412 - val_loss: 3.3064 - val_mae: 1.3654
# Epoch 322/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2445 - mae: 1.3561 - val_loss: 3.6460 - val_mae: 1.4767
# Epoch 323/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.4389 - mae: 1.4149 - val_loss: 3.3594 - val_mae: 1.4459
# Epoch 324/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2773 - mae: 1.3751 - val_loss: 3.5532 - val_mae: 1.4389
# Epoch 325/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2457 - mae: 1.3709 - val_loss: 3.1297 - val_mae: 1.3646
# Epoch 326/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0701 - mae: 1.3258 - val_loss: 3.0891 - val_mae: 1.3399
# Epoch 327/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0265 - mae: 1.3067 - val_loss: 3.2309 - val_mae: 1.3814
# Epoch 328/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1245 - mae: 1.3396 - val_loss: 3.1177 - val_mae: 1.3460
# Epoch 329/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0721 - mae: 1.3264 - val_loss: 3.2146 - val_mae: 1.3455
# Epoch 330/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9588 - mae: 1.2924 - val_loss: 3.4781 - val_mae: 1.4143
# Epoch 331/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2563 - mae: 1.3634 - val_loss: 3.6553 - val_mae: 1.4401
# Epoch 332/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3712 - mae: 1.3800 - val_loss: 3.5610 - val_mae: 1.4658
# Epoch 333/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2207 - mae: 1.3652 - val_loss: 3.1935 - val_mae: 1.3775
# Epoch 334/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2582 - mae: 1.3605 - val_loss: 3.5875 - val_mae: 1.4211
# Epoch 335/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8773 - mae: 1.4852 - val_loss: 3.9808 - val_mae: 1.4636
# Epoch 336/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.9756 - mae: 1.4707 - val_loss: 3.9373 - val_mae: 1.5679
# Epoch 337/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2048 - mae: 1.3628 - val_loss: 3.1169 - val_mae: 1.3386
# Epoch 338/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0055 - mae: 1.2958 - val_loss: 3.1673 - val_mae: 1.3842
# Epoch 339/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0876 - mae: 1.3372 - val_loss: 3.4886 - val_mae: 1.4060
# Epoch 340/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2237 - mae: 1.3617 - val_loss: 3.3307 - val_mae: 1.3957
# Epoch 341/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0448 - mae: 1.3210 - val_loss: 4.0444 - val_mae: 1.4734
# Epoch 342/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3955 - mae: 1.4014 - val_loss: 3.6106 - val_mae: 1.4767
# Epoch 343/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.1406 - mae: 1.3380 - val_loss: 3.2834 - val_mae: 1.3868
# Epoch 344/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1510 - mae: 1.3393 - val_loss: 3.2609 - val_mae: 1.3685
# Epoch 345/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0913 - mae: 1.3246 - val_loss: 3.5164 - val_mae: 1.4819
# Epoch 346/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5732 - mae: 1.4522 - val_loss: 3.2437 - val_mae: 1.3701
# Epoch 347/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2704 - mae: 1.3551 - val_loss: 3.2697 - val_mae: 1.3791
# Epoch 348/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2447 - mae: 1.3508 - val_loss: 3.5314 - val_mae: 1.4785
# Epoch 349/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2307 - mae: 1.3711 - val_loss: 3.9488 - val_mae: 1.5417
# Epoch 350/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5608 - mae: 1.4251 - val_loss: 3.1764 - val_mae: 1.3620
# Epoch 351/1000
# ...
# Epoch 888/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1192 - mae: 1.3074 - val_loss: 3.6254 - val_mae: 1.5260
# Epoch 889/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.6591 - mae: 1.2321 - val_loss: 2.7239 - val_mae: 1.2064
# Epoch 890/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7677 - mae: 1.2425 - val_loss: 3.4871 - val_mae: 1.2344
# Epoch 891/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9809 - mae: 1.2659 - val_loss: 2.1978 - val_mae: 1.0562
# Epoch 892/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2218 - mae: 1.0774 - val_loss: 2.3213 - val_mae: 1.1477
# Epoch 893/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4263 - mae: 1.1312 - val_loss: 2.1877 - val_mae: 1.0659
# Epoch 894/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2540 - mae: 1.0931 - val_loss: 2.2786 - val_mae: 1.0895
# Epoch 895/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1664 - mae: 1.0669 - val_loss: 2.6002 - val_mae: 1.1639
# Epoch 896/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3761 - mae: 1.1372 - val_loss: 2.4178 - val_mae: 1.0966
# Epoch 897/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7492 - mae: 1.2454 - val_loss: 2.3037 - val_mae: 1.0707
# Epoch 898/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2624 - mae: 1.0899 - val_loss: 2.1681 - val_mae: 1.0610
# Epoch 899/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1321 - mae: 1.0560 - val_loss: 2.1684 - val_mae: 1.0688
# Epoch 900/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2564 - mae: 1.1139 - val_loss: 2.2044 - val_mae: 1.0675
# Epoch 901/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1127 - mae: 1.0569 - val_loss: 2.2375 - val_mae: 1.0515
# Epoch 902/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5290 - mae: 1.1390 - val_loss: 2.3609 - val_mae: 1.1201
# Epoch 903/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7265 - mae: 1.1954 - val_loss: 2.3878 - val_mae: 1.1317
# Epoch 904/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5978 - mae: 1.1914 - val_loss: 3.2875 - val_mae: 1.3593
# Epoch 905/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2941 - mae: 1.1158 - val_loss: 2.3164 - val_mae: 1.1294
# Epoch 906/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3054 - mae: 1.1157 - val_loss: 2.3007 - val_mae: 1.1306
# Epoch 907/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3726 - mae: 1.1239 - val_loss: 2.1581 - val_mae: 1.0454
# Epoch 908/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2661 - mae: 1.0870 - val_loss: 2.4228 - val_mae: 1.1144
# Epoch 909/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2988 - mae: 1.0970 - val_loss: 2.2310 - val_mae: 1.0826
# Epoch 910/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2541 - mae: 1.0853 - val_loss: 2.2797 - val_mae: 1.0981
# Epoch 911/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2126 - mae: 1.0812 - val_loss: 2.2178 - val_mae: 1.0673
# Epoch 912/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4027 - mae: 1.1246 - val_loss: 2.4394 - val_mae: 1.1392
# Epoch 913/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8420 - mae: 1.2179 - val_loss: 3.2330 - val_mae: 1.2916
# Epoch 914/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6567 - mae: 1.1876 - val_loss: 2.6543 - val_mae: 1.2516
# Epoch 915/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7966 - mae: 1.1805 - val_loss: 2.9024 - val_mae: 1.2639
# Epoch 916/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5382 - mae: 1.3409 - val_loss: 2.5925 - val_mae: 1.1814
# Epoch 917/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6932 - mae: 1.2282 - val_loss: 2.1596 - val_mae: 1.0314
# Epoch 918/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4929 - mae: 1.1632 - val_loss: 2.2495 - val_mae: 1.0895
# Epoch 919/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5272 - mae: 1.1902 - val_loss: 2.1759 - val_mae: 1.0470
# Epoch 920/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 2.1173 - mae: 1.0555 - val_loss: 2.2005 - val_mae: 1.0368
# Epoch 921/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2442 - mae: 1.0807 - val_loss: 2.1680 - val_mae: 1.0408
# Epoch 922/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5636 - mae: 1.1958 - val_loss: 2.6384 - val_mae: 1.1544
# Epoch 923/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4236 - mae: 1.1473 - val_loss: 2.2934 - val_mae: 1.0974
# Epoch 924/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3963 - mae: 1.1346 - val_loss: 2.2653 - val_mae: 1.0532
# Epoch 925/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3381 - mae: 1.1057 - val_loss: 2.2849 - val_mae: 1.0906
# Epoch 926/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2226 - mae: 1.0816 - val_loss: 2.7538 - val_mae: 1.1618
# Epoch 927/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3822 - mae: 1.1110 - val_loss: 2.4088 - val_mae: 1.1077
# Epoch 928/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1289 - mae: 1.0528 - val_loss: 2.1096 - val_mae: 1.0187
# Epoch 929/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3651 - mae: 1.1395 - val_loss: 2.6399 - val_mae: 1.1988
# Epoch 930/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5301 - mae: 1.1911 - val_loss: 2.4547 - val_mae: 1.1430
# Epoch 931/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2047 - mae: 1.0847 - val_loss: 2.4896 - val_mae: 1.0948
# Epoch 932/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4808 - mae: 1.1572 - val_loss: 2.5555 - val_mae: 1.2151
# Epoch 933/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6510 - mae: 1.2100 - val_loss: 3.0297 - val_mae: 1.1942
# Epoch 934/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.7165 - mae: 1.2047 - val_loss: 2.8363 - val_mae: 1.1878
# Epoch 935/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4028 - mae: 1.1175 - val_loss: 2.7811 - val_mae: 1.1681
# Epoch 936/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4966 - mae: 1.1497 - val_loss: 2.3031 - val_mae: 1.0846
# Epoch 937/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4851 - mae: 1.1462 - val_loss: 2.5559 - val_mae: 1.1867
# Epoch 938/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1038 - mae: 1.0472 - val_loss: 2.9026 - val_mae: 1.1943
# Epoch 939/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3435 - mae: 1.2697 - val_loss: 2.6295 - val_mae: 1.1661
# Epoch 940/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8292 - mae: 1.2289 - val_loss: 2.1695 - val_mae: 1.0468
# Epoch 941/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3394 - mae: 1.1015 - val_loss: 2.4750 - val_mae: 1.0991
# Epoch 942/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5844 - mae: 1.1511 - val_loss: 2.4748 - val_mae: 1.0830
# Epoch 943/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2729 - mae: 1.1043 - val_loss: 2.1784 - val_mae: 1.0400
# Epoch 944/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0757 - mae: 1.0328 - val_loss: 2.2087 - val_mae: 1.0969
# Epoch 945/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1623 - mae: 1.0775 - val_loss: 2.7813 - val_mae: 1.1889
# Epoch 946/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2841 - mae: 1.0982 - val_loss: 2.5873 - val_mae: 1.1317
# Epoch 947/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4517 - mae: 1.1399 - val_loss: 2.6762 - val_mae: 1.1862
# Epoch 948/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2327 - mae: 1.0959 - val_loss: 2.1007 - val_mae: 1.0259
# Epoch 949/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2351 - mae: 1.1047 - val_loss: 2.3133 - val_mae: 1.1208
# Epoch 950/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2501 - mae: 1.0999 - val_loss: 2.4157 - val_mae: 1.1693
# Epoch 951/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4641 - mae: 1.1320 - val_loss: 2.3431 - val_mae: 1.1015
# Epoch 952/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4830 - mae: 1.1500 - val_loss: 3.2475 - val_mae: 1.2389
# Epoch 953/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4677 - mae: 1.3769 - val_loss: 3.6934 - val_mae: 1.3094
# Epoch 954/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2212 - mae: 1.3269 - val_loss: 3.2195 - val_mae: 1.2972
# Epoch 955/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5325 - mae: 1.1609 - val_loss: 2.1352 - val_mae: 1.0410
# Epoch 956/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1119 - mae: 1.0469 - val_loss: 2.0895 - val_mae: 1.0227
# Epoch 957/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1574 - mae: 1.0599 - val_loss: 2.2332 - val_mae: 1.0954
# Epoch 958/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1740 - mae: 1.0746 - val_loss: 2.5105 - val_mae: 1.1704
# Epoch 959/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2384 - mae: 1.0898 - val_loss: 2.1697 - val_mae: 1.0416
# Epoch 960/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1312 - mae: 1.0583 - val_loss: 2.2142 - val_mae: 1.0482
# Epoch 961/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1395 - mae: 1.0630 - val_loss: 2.1584 - val_mae: 1.0364
# Epoch 962/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3525 - mae: 1.1220 - val_loss: 2.9734 - val_mae: 1.2299
# Epoch 963/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1059 - mae: 1.3226 - val_loss: 3.3984 - val_mae: 1.4597
# Epoch 964/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7422 - mae: 1.2419 - val_loss: 2.8666 - val_mae: 1.2594
# Epoch 965/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5483 - mae: 1.1755 - val_loss: 2.4780 - val_mae: 1.1324
# Epoch 966/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1167 - mae: 1.0441 - val_loss: 2.1762 - val_mae: 1.0695
# Epoch 967/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1654 - mae: 1.0729 - val_loss: 2.3893 - val_mae: 1.1185
# Epoch 968/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8449 - mae: 1.1930 - val_loss: 2.1873 - val_mae: 1.0856
# Epoch 969/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6364 - mae: 1.1560 - val_loss: 2.2063 - val_mae: 1.0527
# Epoch 970/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3024 - mae: 1.1124 - val_loss: 2.7007 - val_mae: 1.2370
# Epoch 971/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5485 - mae: 1.1406 - val_loss: 2.3125 - val_mae: 1.1264
# Epoch 972/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2280 - mae: 1.0801 - val_loss: 2.4625 - val_mae: 1.2004
# Epoch 973/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1812 - mae: 1.0768 - val_loss: 2.5092 - val_mae: 1.0854
# Epoch 974/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3285 - mae: 1.1013 - val_loss: 2.5803 - val_mae: 1.1745
# Epoch 975/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4954 - mae: 1.1721 - val_loss: 2.6027 - val_mae: 1.2178
# Epoch 976/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3005 - mae: 1.1229 - val_loss: 2.4516 - val_mae: 1.0963
# Epoch 977/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1609 - mae: 1.0602 - val_loss: 2.2556 - val_mae: 1.0961
# Epoch 978/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1788 - mae: 1.0617 - val_loss: 2.7465 - val_mae: 1.1951
# Epoch 979/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1763 - mae: 1.0663 - val_loss: 2.3468 - val_mae: 1.0991
# Epoch 980/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1871 - mae: 1.0681 - val_loss: 2.4407 - val_mae: 1.1131
# Epoch 981/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2240 - mae: 1.0848 - val_loss: 2.4894 - val_mae: 1.1223
# Epoch 982/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3047 - mae: 1.1133 - val_loss: 2.2929 - val_mae: 1.1067
# Epoch 983/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1532 - mae: 1.0745 - val_loss: 2.1654 - val_mae: 1.0734
# Epoch 984/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4405 - mae: 1.1483 - val_loss: 2.4345 - val_mae: 1.1098
# Epoch 985/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4169 - mae: 1.1328 - val_loss: 2.4822 - val_mae: 1.1145
# Epoch 986/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3648 - mae: 1.0864 - val_loss: 2.8420 - val_mae: 1.2454
# Epoch 987/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3527 - mae: 1.1136 - val_loss: 2.1666 - val_mae: 1.0341
# Epoch 988/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2201 - mae: 1.0724 - val_loss: 2.5585 - val_mae: 1.2005
# Epoch 989/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3146 - mae: 1.1260 - val_loss: 2.3535 - val_mae: 1.0886
# Epoch 990/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2844 - mae: 1.1000 - val_loss: 2.3800 - val_mae: 1.1137
# Epoch 991/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 2.4707 - mae: 1.1524 - val_loss: 2.1947 - val_mae: 1.0519
# Epoch 992/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5347 - mae: 1.1759 - val_loss: 2.4463 - val_mae: 1.1653
# Epoch 993/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2764 - mae: 1.1024 - val_loss: 2.3340 - val_mae: 1.0833
# Epoch 994/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3913 - mae: 1.1197 - val_loss: 2.2790 - val_mae: 1.1136
# Epoch 995/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9404 - mae: 1.2720 - val_loss: 2.5993 - val_mae: 1.1773
# Epoch 996/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1150 - mae: 1.0397 - val_loss: 2.5487 - val_mae: 1.1868
# Epoch 997/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8468 - mae: 1.2754 - val_loss: 3.3835 - val_mae: 1.3849
# Epoch 998/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5859 - mae: 1.1924 - val_loss: 2.3622 - val_mae: 1.1016
# Epoch 999/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2250 - mae: 1.0963 - val_loss: 2.0749 - val_mae: 1.0105
# Epoch 1000/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0746 - mae: 1.0334 - val_loss: 2.0752 - val_mae: 1.0131
# 1/1 [==============================] - 0s 56ms/step
# Predicted values are:  [[ 79.68245  137.31682  188.31468 ]
#  [ 87.71758  141.086    183.05502 ]
#  [ 82.659424 139.11963  182.36719 ]
#  [ 85.29427  142.98973  188.06415 ]
#  [ 82.56387  139.00488  184.31714 ]]
# Real values are:       Substrate Thickness  Patch Length  Patch Width
# 190                   80           137          189
# 636                   87           142          183
# 312                   83           139          181
# 784                   85           143          188
# 481                   82           140          188
# 7/7 [==============================] - 0s 2ms/step - loss: 17.3400 - mae: 1.2550
# Mean squared error from neural net:  17.34000015258789
# Mean absolute error from neural net:  1.2550498247146606

# %%
history_dict = history.history
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
from __future__ import absolute_import, division, print_function

import pathlib
import pandas
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)

def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation=tf.nn.relu, input_shape=[3]),
        layers.Dense(64, activation=tf.nn.relu),
        layers.Dense(3)
    ])

    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse', optimizer=optimizer, metrics=['mae', 'mse'])

    return model

model = build_model()
# Out:
# 2.12.0

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 64)                256
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dense_13 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 4,611
# Trainable params: 4,611
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = model.predict(X_test_scaled[:5])
print("Predicted values are: \n", predictions)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Predicted values are:
#  [[-0.09742586  0.22095972  0.09305312]
#  [-0.08201828  0.19252391 -0.03280456]
#  [-0.057517    0.27284282  0.01640146]
#  [-0.07915493  0.15089957  0.06450693]
#  [-0.05936565  0.22221646 -0.07363758]]

# %%
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end ='')

EPOCHS = 20

history = model.fit(
    X_train_scaled, y_train, validation_split=0.2, epochs=EPOCHS, verbose=0, callbacks=[PrintDot()]
)
# Out:
# ....................

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

lr_model = linear_model.LinearRegression()
lr_model.fit(X_train_scaled, y_train)
y_pred_lr = lr_model.predict(X_test_scaled)
mse_lr = mean_squared_error(y_test, y_pred_lr)
mae_lr = mean_absolute_error(y_test, y_pred_lr)
print('Mean squared error from linear regression: ', mse_lr)
print('Mean absolute error from linear regression: ', mae_lr)
# Out:
# Mean squared error from linear regression:  33.16543519504176
# Mean absolute error from linear regression:  2.232313675273073

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 200, random_state=20)
model.fit(X_train_scaled, y_train)


y_pred_RF = model.predict(X_test_scaled)

mse_RF = mean_squared_error(y_test, y_pred_RF)
mae_RF = mean_absolute_error(y_test, y_pred_RF)
print('Mean squared error using Random Forest: ', mse_RF)
print('Mean absolute error Using Random Forest: ', mae_RF)

predictions = model.predict(X_test_scaled[:5])
print("Predicted values are: \n", predictions)
print("Real values are: \n", y_test[:5])
# Out:
# Mean squared error using Random Forest:  27.09080409238113
# Mean absolute error Using Random Forest:  1.7862263760833341
# Predicted values are:
#  [[  0.6717025 -22.87895     9.046983 ]
#  [  0.685036  -32.12935     8.9632265]
#  [  0.658072  -19.387355    9.475701 ]
#  [  0.681958  -45.645305    8.812678 ]
#  [  0.6720535 -29.75395     9.1482085]]
# Real values are:
#       Frequency  Return Loss (s11)    Gain
# 741     0.6724            -22.928  9.0172
# 404     0.6805            -35.134  8.9444
# 530     0.6544            -18.841  9.6034
# 347     0.6877            -29.185  8.7434
# 471     0.6733            -30.347  9.1131

# %%
import numpy as np
import matplotlib.pyplot as plt
 
 
def per(x,y):
    num = 1
    while x != y:
        if x > y:
            x = x-(1/num)
        else:
            x = x+(1/num)
        num += 1
    return num
 
 
y1 = 2 #number with footprint
 
if int(input('Zoom search = 1, Normal search = 0:')) == 1:
    peak = float(input('Enter peak:'))
    search = float(input('Enter Search area:'))
    leng = int(input('Enter sample amount:'))
    l1 = np.zeros(leng)
    x1 = np.linspace(peak-(search*0.5),peak+(search*0.5), leng)
else:
    leng= int(input('Enter sample amount:'))
    x1 = np.linspace(0,2,leng)
    l1 = np.zeros(leng)
 
for i in range(leng):
    l1[i] = per(x1[i],y1)
l2 = l1
 
 
#max checker
for n in range(16):
    print(x1[np.argmax(l2)], np.max(l2))
    l2[np.argmax(l1)] = y1
 
plt.plot(x1,l1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 18
#      13     return num
#      16 y1 = 2 #number with footprint
# ---> 18 if int(input('Zoom search = 1, Normal search = 0:')) == 1:
#      19     peak = float(input('Enter peak:'))
#      20     search = float(input('Enter Search area:'))
#
# ValueError: invalid literal for int() with base 10: ''
