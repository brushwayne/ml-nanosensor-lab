# %%
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import pandas as pd

df = read_csv("./database/run1.csv", delim_whitespace=False, header=None)

df = df.iloc[1:]

feature_names = ['Serial Number', 'Substrate Thickness', 'Patch Length', 'Patch Width', 'Frequency', 'Return Loss (s11)', 'Gain']

df.columns = feature_names

df = df.apply(pd.to_numeric)

y = df[['Substrate Thickness', 'Patch Length', 'Patch Width']]
x = df[['Frequency', 'Return Loss (s11)', 'Gain']]

print(df.head())

print(df.info())
# Out:
#    Serial Number  Substrate Thickness  Patch Length  Patch Width  Frequency  \
# 1              1                   80           136          180     0.6535
# 2              3                   82           136          180     0.6769
# 3              4                   83           136          180     0.6805
# 4              5                   84           136          180     0.6841
# 5              6                   85           136          180     0.6841
#
#    Return Loss (s11)    Gain
# 1            -23.114  9.9730
# 2            -32.885  9.2812
# 3            -56.370  9.1623
# 4            -47.889  9.0913
# 5            -38.306  9.0199
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 1 to 998
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Serial Number        998 non-null    int64
#  1   Substrate Thickness  998 non-null    int64
#  2   Patch Length         998 non-null    int64
#  3   Patch Width          998 non-null    int64
#  4   Frequency            998 non-null    float64
#  5   Return Loss (s11)    998 non-null    float64
#  6   Gain                 998 non-null    float64
# dtypes: float64(3), int64(4)
# memory usage: 54.7 KB
# None

# %%
import random

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = random.randint(256, 999))

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)

model = Sequential()
model.add(Dense(128, input_dim=3, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
#Output layer
model.add(Dense(3, activation='linear'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
model.summary()

history = model.fit(X_train_scaled, y_train, validation_split=0.20, epochs = 1000)

from matplotlib import pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['mae']
val_acc = history.history['val_mae']
plt.plot(epochs, acc, 'y', label='Training MAE')
plt.plot(epochs, val_acc, 'r', label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


predictions = model.predict(X_test_scaled[:5])
print("Predicted values are: ", predictions)
print("Real values are: ", y_test[:5])

mse_neural, mae_neural = model.evaluate(X_test_scaled, y_test)
print('Mean squared error from neural net: ', mse_neural)
print('Mean absolute error from neural net: ', mae_neural)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               512
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 33,923
# Trainable params: 33,923
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 20/20 [==============================] - 2s 26ms/step - loss: 20113.1133 - mae: 135.8484 - val_loss: 19775.3066 - val_mae: 134.6679
# Epoch 2/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 18442.0352 - mae: 129.8040 - val_loss: 16083.5000 - val_mae: 120.8006
# Epoch 3/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 11383.5342 - mae: 98.6228 - val_loss: 5623.5474 - val_mae: 66.7180
# Epoch 4/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3110.8552 - mae: 44.3347 - val_loss: 2035.2607 - val_mae: 33.0190
# Epoch 5/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 1577.7909 - mae: 28.9903 - val_loss: 1282.5188 - val_mae: 26.9650
# Epoch 6/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 1097.0051 - mae: 23.4457 - val_loss: 950.5031 - val_mae: 20.5621
# Epoch 7/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 867.1172 - mae: 18.2832 - val_loss: 754.3569 - val_mae: 18.4089
# Epoch 8/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 672.9609 - mae: 16.4873 - val_loss: 587.4096 - val_mae: 15.1303
# Epoch 9/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 538.9829 - mae: 14.0181 - val_loss: 478.2702 - val_mae: 13.0207
# Epoch 10/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 448.7088 - mae: 11.4779 - val_loss: 407.9648 - val_mae: 11.8909
# Epoch 11/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 380.6887 - mae: 11.2479 - val_loss: 332.3938 - val_mae: 10.2593
# Epoch 12/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 317.1693 - mae: 9.8656 - val_loss: 277.8983 - val_mae: 9.8393
# Epoch 13/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 260.6491 - mae: 8.7447 - val_loss: 235.3692 - val_mae: 8.7561
# Epoch 14/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 223.2218 - mae: 8.2902 - val_loss: 197.9375 - val_mae: 7.4914
# Epoch 15/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 186.4436 - mae: 7.2987 - val_loss: 173.6364 - val_mae: 7.8324
# Epoch 16/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 166.5008 - mae: 6.8275 - val_loss: 146.8294 - val_mae: 7.2693
# Epoch 17/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 143.2070 - mae: 6.8872 - val_loss: 125.3359 - val_mae: 6.0163
# Epoch 18/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 119.6029 - mae: 6.1037 - val_loss: 105.0060 - val_mae: 6.0637
# Epoch 19/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 103.1833 - mae: 5.4163 - val_loss: 92.5051 - val_mae: 5.6591
# Epoch 20/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 90.8359 - mae: 5.2333 - val_loss: 79.0790 - val_mae: 5.1524
# Epoch 21/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 78.4621 - mae: 5.0140 - val_loss: 68.5753 - val_mae: 4.9006
# Epoch 22/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 68.7079 - mae: 4.4633 - val_loss: 62.0700 - val_mae: 4.8477
# Epoch 23/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 63.2015 - mae: 4.4549 - val_loss: 53.6097 - val_mae: 4.5911
# Epoch 24/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 52.3204 - mae: 4.2272 - val_loss: 46.5159 - val_mae: 4.0684
# Epoch 25/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 47.8138 - mae: 3.9854 - val_loss: 40.1900 - val_mae: 3.8043
# Epoch 26/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 42.3676 - mae: 3.8800 - val_loss: 36.5174 - val_mae: 3.7251
# Epoch 27/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 36.7989 - mae: 3.5598 - val_loss: 32.2008 - val_mae: 3.5764
# Epoch 28/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 32.1374 - mae: 3.4065 - val_loss: 28.3095 - val_mae: 3.2597
# Epoch 29/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 28.8552 - mae: 3.2274 - val_loss: 25.8222 - val_mae: 3.1270
# Epoch 30/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 25.3278 - mae: 3.0544 - val_loss: 23.0379 - val_mae: 3.1678
# Epoch 31/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 22.5835 - mae: 3.0212 - val_loss: 21.1469 - val_mae: 3.0098
# Epoch 32/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 21.1969 - mae: 2.9774 - val_loss: 19.4806 - val_mae: 2.8605
# Epoch 33/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 19.0706 - mae: 2.8827 - val_loss: 18.2178 - val_mae: 2.8025
# Epoch 34/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 17.0903 - mae: 2.7442 - val_loss: 16.0553 - val_mae: 2.6848
# Epoch 35/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 15.9755 - mae: 2.6258 - val_loss: 14.9755 - val_mae: 2.6539
# Epoch 36/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 14.3691 - mae: 2.5666 - val_loss: 14.1690 - val_mae: 2.6392
# Epoch 37/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 13.2079 - mae: 2.5043 - val_loss: 12.9006 - val_mae: 2.5329
# Epoch 38/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 12.4730 - mae: 2.4315 - val_loss: 12.2919 - val_mae: 2.4901
# Epoch 39/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 11.6615 - mae: 2.4316 - val_loss: 11.5539 - val_mae: 2.4464
# Epoch 40/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 11.0420 - mae: 2.3865 - val_loss: 11.5945 - val_mae: 2.4883
# Epoch 41/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 10.5625 - mae: 2.3500 - val_loss: 10.7712 - val_mae: 2.4331
# Epoch 42/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 9.9408 - mae: 2.2931 - val_loss: 10.4887 - val_mae: 2.3992
# Epoch 43/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 9.9072 - mae: 2.3418 - val_loss: 10.4326 - val_mae: 2.4049
# Epoch 44/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 9.1688 - mae: 2.2394 - val_loss: 9.9222 - val_mae: 2.3764
# Epoch 45/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 8.7491 - mae: 2.1985 - val_loss: 9.0318 - val_mae: 2.2680
# Epoch 46/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 8.3357 - mae: 2.1576 - val_loss: 8.6310 - val_mae: 2.2191
# Epoch 47/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 8.1424 - mae: 2.1261 - val_loss: 8.5950 - val_mae: 2.2213
# Epoch 48/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.9401 - mae: 2.1062 - val_loss: 8.2937 - val_mae: 2.1670
# Epoch 49/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 7.7991 - mae: 2.1340 - val_loss: 8.2966 - val_mae: 2.1887
# Epoch 50/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.5602 - mae: 2.0715 - val_loss: 7.8508 - val_mae: 2.1306
# Epoch 51/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.4342 - mae: 2.0685 - val_loss: 7.9415 - val_mae: 2.1293
# Epoch 52/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.2048 - mae: 2.0267 - val_loss: 7.7002 - val_mae: 2.1106
# Epoch 53/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.1104 - mae: 2.0310 - val_loss: 7.6826 - val_mae: 2.1050
# Epoch 54/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.0129 - mae: 2.0178 - val_loss: 7.4079 - val_mae: 2.0790
# Epoch 55/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 7.0110 - mae: 2.0058 - val_loss: 7.9867 - val_mae: 2.1573
# Epoch 56/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 6.9273 - mae: 2.0193 - val_loss: 7.5899 - val_mae: 2.0979
# Epoch 57/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 6.7767 - mae: 1.9821 - val_loss: 7.1700 - val_mae: 2.0347
# Epoch 58/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 6.5300 - mae: 1.9417 - val_loss: 7.4003 - val_mae: 2.1070
# Epoch 59/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.6695 - mae: 1.9771 - val_loss: 7.0273 - val_mae: 2.0185
# Epoch 60/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 6.5561 - mae: 1.9579 - val_loss: 6.9401 - val_mae: 2.0548
# Epoch 61/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.5080 - mae: 1.9466 - val_loss: 6.8907 - val_mae: 2.0021
# Epoch 62/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 6.5887 - mae: 1.9571 - val_loss: 6.9997 - val_mae: 2.0324
# Epoch 63/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.3515 - mae: 1.9248 - val_loss: 6.8554 - val_mae: 1.9756
# Epoch 64/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.4769 - mae: 1.9532 - val_loss: 7.1472 - val_mae: 2.0592
# Epoch 65/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.4649 - mae: 1.9366 - val_loss: 6.9223 - val_mae: 2.0331
# Epoch 66/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.2420 - mae: 1.9157 - val_loss: 6.6213 - val_mae: 1.9696
# Epoch 67/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.2407 - mae: 1.9243 - val_loss: 6.6054 - val_mae: 1.9914
# Epoch 68/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.2194 - mae: 1.9037 - val_loss: 6.6840 - val_mae: 1.9890
# Epoch 69/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.1109 - mae: 1.8890 - val_loss: 6.6464 - val_mae: 1.9760
# Epoch 70/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.0135 - mae: 1.8833 - val_loss: 6.5545 - val_mae: 1.9654
# Epoch 71/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 6.1844 - mae: 1.9076 - val_loss: 7.0030 - val_mae: 2.0572
# Epoch 72/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 6.1089 - mae: 1.8869 - val_loss: 6.9596 - val_mae: 2.0220
# Epoch 73/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 6.0929 - mae: 1.8869 - val_loss: 6.7572 - val_mae: 1.9842
# Epoch 74/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.9851 - mae: 1.8774 - val_loss: 6.5282 - val_mae: 1.9416
# Epoch 75/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.8603 - mae: 1.8555 - val_loss: 6.6018 - val_mae: 1.9608
# Epoch 76/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.8737 - mae: 1.8542 - val_loss: 6.4825 - val_mae: 1.9425
# Epoch 77/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.8167 - mae: 1.8667 - val_loss: 6.6767 - val_mae: 1.9763
# Epoch 78/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.7891 - mae: 1.8522 - val_loss: 6.4908 - val_mae: 1.9405
# Epoch 79/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.7965 - mae: 1.8637 - val_loss: 6.3917 - val_mae: 1.9329
# Epoch 80/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.7325 - mae: 1.8433 - val_loss: 6.3819 - val_mae: 1.9257
# Epoch 81/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.6534 - mae: 1.8312 - val_loss: 6.3303 - val_mae: 1.9322
# Epoch 82/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.6541 - mae: 1.8434 - val_loss: 6.3152 - val_mae: 1.9159
# Epoch 83/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.6447 - mae: 1.8345 - val_loss: 6.4868 - val_mae: 1.9424
# Epoch 84/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.6668 - mae: 1.8419 - val_loss: 6.5679 - val_mae: 1.9425
# Epoch 85/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.6644 - mae: 1.8389 - val_loss: 6.2233 - val_mae: 1.8982
# Epoch 86/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.5522 - mae: 1.8210 - val_loss: 6.1777 - val_mae: 1.8968
# Epoch 87/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 5.5478 - mae: 1.8190 - val_loss: 6.2777 - val_mae: 1.9095
# Epoch 88/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.5240 - mae: 1.8179 - val_loss: 6.3485 - val_mae: 1.9204
# Epoch 89/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.4701 - mae: 1.8139 - val_loss: 6.3603 - val_mae: 1.9238
# Epoch 90/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 5.4806 - mae: 1.8106 - val_loss: 6.2262 - val_mae: 1.9106
# Epoch 91/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.5198 - mae: 1.8355 - val_loss: 6.3490 - val_mae: 1.9423
# Epoch 92/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.4400 - mae: 1.8015 - val_loss: 6.2291 - val_mae: 1.9151
# Epoch 93/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.3455 - mae: 1.7942 - val_loss: 6.3254 - val_mae: 1.9303
# Epoch 94/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.3691 - mae: 1.8038 - val_loss: 6.2297 - val_mae: 1.8606
# Epoch 95/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.3840 - mae: 1.8040 - val_loss: 6.2935 - val_mae: 1.8908
# Epoch 96/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.3276 - mae: 1.7811 - val_loss: 6.0181 - val_mae: 1.8643
# Epoch 97/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.3243 - mae: 1.7850 - val_loss: 6.3203 - val_mae: 1.8989
# Epoch 98/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 5.2643 - mae: 1.7821 - val_loss: 6.2304 - val_mae: 1.8922
# Epoch 99/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.2581 - mae: 1.7817 - val_loss: 6.2912 - val_mae: 1.9050
# Epoch 100/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.2368 - mae: 1.7842 - val_loss: 6.0446 - val_mae: 1.8505
# Epoch 101/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 5.2296 - mae: 1.7752 - val_loss: 6.3805 - val_mae: 1.8805
# Epoch 102/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.2115 - mae: 1.7751 - val_loss: 6.1955 - val_mae: 1.8687
# Epoch 103/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.0987 - mae: 1.7542 - val_loss: 6.1389 - val_mae: 1.8739
# Epoch 104/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 5.0708 - mae: 1.7531 - val_loss: 6.1624 - val_mae: 1.8964
# Epoch 105/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 5.0143 - mae: 1.7524 - val_loss: 6.0678 - val_mae: 1.8511
# Epoch 106/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.0145 - mae: 1.7381 - val_loss: 6.1502 - val_mae: 1.8623
# Epoch 107/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.0156 - mae: 1.7372 - val_loss: 6.4048 - val_mae: 1.8893
# Epoch 108/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.0132 - mae: 1.7407 - val_loss: 6.1966 - val_mae: 1.8410
# Epoch 109/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 5.0290 - mae: 1.7474 - val_loss: 6.1708 - val_mae: 1.8500
# Epoch 110/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.9047 - mae: 1.7244 - val_loss: 6.0975 - val_mae: 1.8339
# Epoch 111/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.9739 - mae: 1.7403 - val_loss: 6.2606 - val_mae: 1.8363
# Epoch 112/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 4.9556 - mae: 1.7379 - val_loss: 6.4489 - val_mae: 1.8506
# Epoch 113/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.9579 - mae: 1.7472 - val_loss: 6.3231 - val_mae: 1.8530
# Epoch 114/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.9600 - mae: 1.7378 - val_loss: 6.3847 - val_mae: 1.8484
# Epoch 115/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.8851 - mae: 1.7128 - val_loss: 6.1767 - val_mae: 1.8514
# Epoch 116/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.8479 - mae: 1.7126 - val_loss: 6.4192 - val_mae: 1.8445
# Epoch 117/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.8743 - mae: 1.7304 - val_loss: 6.3423 - val_mae: 1.8746
# Epoch 118/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.9445 - mae: 1.7277 - val_loss: 6.4195 - val_mae: 1.8810
# Epoch 119/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.8718 - mae: 1.7252 - val_loss: 6.3739 - val_mae: 1.8676
# Epoch 120/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.8517 - mae: 1.7154 - val_loss: 6.2336 - val_mae: 1.8205
# Epoch 121/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 4.6873 - mae: 1.6830 - val_loss: 6.2272 - val_mae: 1.8259
# Epoch 122/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.7184 - mae: 1.6946 - val_loss: 6.3571 - val_mae: 1.8581
# Epoch 123/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.8185 - mae: 1.7199 - val_loss: 6.4750 - val_mae: 1.8664
# Epoch 124/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.7538 - mae: 1.6966 - val_loss: 6.5641 - val_mae: 1.8917
# Epoch 125/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.7813 - mae: 1.7287 - val_loss: 6.7578 - val_mae: 1.8687
# Epoch 126/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.6423 - mae: 1.6916 - val_loss: 6.4649 - val_mae: 1.8248
# Epoch 127/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.6715 - mae: 1.6880 - val_loss: 6.6609 - val_mae: 1.8026
# Epoch 128/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.6179 - mae: 1.6846 - val_loss: 6.6147 - val_mae: 1.8410
# Epoch 129/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.5319 - mae: 1.6608 - val_loss: 6.4633 - val_mae: 1.8001
# Epoch 130/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.5002 - mae: 1.6547 - val_loss: 6.4184 - val_mae: 1.8162
# Epoch 131/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.6050 - mae: 1.6871 - val_loss: 6.5590 - val_mae: 1.7817
# Epoch 132/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.5884 - mae: 1.6809 - val_loss: 6.4417 - val_mae: 1.7711
# Epoch 133/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.5689 - mae: 1.6715 - val_loss: 6.6201 - val_mae: 1.7963
# Epoch 134/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4506 - mae: 1.6451 - val_loss: 6.5700 - val_mae: 1.7929
# Epoch 135/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4272 - mae: 1.6390 - val_loss: 6.8700 - val_mae: 1.7830
# Epoch 136/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.4673 - mae: 1.6603 - val_loss: 6.7244 - val_mae: 1.7830
# Epoch 137/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.3719 - mae: 1.6352 - val_loss: 6.8873 - val_mae: 1.8150
# Epoch 138/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.3958 - mae: 1.6386 - val_loss: 6.7262 - val_mae: 1.7741
# Epoch 139/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4319 - mae: 1.6489 - val_loss: 7.0126 - val_mae: 1.7746
# Epoch 140/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4369 - mae: 1.6394 - val_loss: 6.7238 - val_mae: 1.7953
# Epoch 141/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.4122 - mae: 1.6251 - val_loss: 6.7940 - val_mae: 1.7857
# Epoch 142/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4305 - mae: 1.6330 - val_loss: 6.9305 - val_mae: 1.7866
# Epoch 143/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2758 - mae: 1.6160 - val_loss: 7.1029 - val_mae: 1.7675
# Epoch 144/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.2955 - mae: 1.6176 - val_loss: 6.8747 - val_mae: 1.7645
# Epoch 145/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2935 - mae: 1.6156 - val_loss: 7.2402 - val_mae: 1.7829
# Epoch 146/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.2560 - mae: 1.6084 - val_loss: 7.1728 - val_mae: 1.7785
# Epoch 147/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.3460 - mae: 1.6261 - val_loss: 7.2353 - val_mae: 1.7694
# Epoch 148/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2696 - mae: 1.6113 - val_loss: 7.3149 - val_mae: 1.7595
# Epoch 149/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2316 - mae: 1.6082 - val_loss: 7.4905 - val_mae: 1.7755
# Epoch 150/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2116 - mae: 1.5947 - val_loss: 7.3419 - val_mae: 1.7785
# Epoch 151/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2261 - mae: 1.6059 - val_loss: 7.6941 - val_mae: 1.8538
# Epoch 152/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2515 - mae: 1.6029 - val_loss: 7.5331 - val_mae: 1.7822
# Epoch 153/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.1537 - mae: 1.5819 - val_loss: 7.3273 - val_mae: 1.7864
# Epoch 154/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2919 - mae: 1.6069 - val_loss: 7.5256 - val_mae: 1.7892
# Epoch 155/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.3391 - mae: 1.6159 - val_loss: 7.8464 - val_mae: 1.8457
# Epoch 156/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4829 - mae: 1.6332 - val_loss: 7.7933 - val_mae: 1.8001
# Epoch 157/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2923 - mae: 1.6116 - val_loss: 7.7293 - val_mae: 1.7790
# Epoch 158/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.0556 - mae: 1.5674 - val_loss: 7.5818 - val_mae: 1.7784
# Epoch 159/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.1340 - mae: 1.5825 - val_loss: 7.5102 - val_mae: 1.7371
# Epoch 160/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.1933 - mae: 1.5989 - val_loss: 7.8578 - val_mae: 1.7504
# Epoch 161/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9964 - mae: 1.5577 - val_loss: 7.6380 - val_mae: 1.7500
# Epoch 162/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.0373 - mae: 1.5606 - val_loss: 7.8416 - val_mae: 1.7508
# Epoch 163/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.0216 - mae: 1.5474 - val_loss: 8.0359 - val_mae: 1.7686
# Epoch 164/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9356 - mae: 1.5403 - val_loss: 7.8725 - val_mae: 1.7230
# Epoch 165/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 4.0511 - mae: 1.5636 - val_loss: 8.0721 - val_mae: 1.7171
# Epoch 166/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 4.1636 - mae: 1.5774 - val_loss: 8.1290 - val_mae: 1.7871
# Epoch 167/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.4906 - mae: 1.6290 - val_loss: 8.4350 - val_mae: 1.8708
# Epoch 168/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.3689 - mae: 1.6217 - val_loss: 8.0438 - val_mae: 1.7307
# Epoch 169/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.0338 - mae: 1.5645 - val_loss: 8.1130 - val_mae: 1.7546
# Epoch 170/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9268 - mae: 1.5385 - val_loss: 8.3143 - val_mae: 1.7123
# Epoch 171/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9158 - mae: 1.5331 - val_loss: 8.2229 - val_mae: 1.6983
# Epoch 172/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8962 - mae: 1.5258 - val_loss: 8.3253 - val_mae: 1.7774
# Epoch 173/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.1201 - mae: 1.5707 - val_loss: 8.3184 - val_mae: 1.7376
# Epoch 174/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9188 - mae: 1.5276 - val_loss: 8.2806 - val_mae: 1.7028
# Epoch 175/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9407 - mae: 1.5394 - val_loss: 8.3514 - val_mae: 1.6938
# Epoch 176/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.1264 - mae: 1.5727 - val_loss: 9.1760 - val_mae: 1.8708
# Epoch 177/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.1530 - mae: 1.5780 - val_loss: 8.9953 - val_mae: 1.7498
# Epoch 178/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.9064 - mae: 1.5239 - val_loss: 8.4359 - val_mae: 1.7148
# Epoch 179/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8326 - mae: 1.5170 - val_loss: 9.0391 - val_mae: 1.7461
# Epoch 180/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 4.0194 - mae: 1.5557 - val_loss: 8.7860 - val_mae: 1.7575
# Epoch 181/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.9146 - mae: 1.5350 - val_loss: 8.7004 - val_mae: 1.7348
# Epoch 182/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.8989 - mae: 1.5367 - val_loss: 8.8568 - val_mae: 1.7108
# Epoch 183/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.7693 - mae: 1.5017 - val_loss: 8.9684 - val_mae: 1.7179
# Epoch 184/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.8379 - mae: 1.5256 - val_loss: 9.0526 - val_mae: 1.7386
# Epoch 185/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.8434 - mae: 1.5225 - val_loss: 8.9697 - val_mae: 1.7110
# Epoch 186/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.8497 - mae: 1.5151 - val_loss: 8.9700 - val_mae: 1.7361
# Epoch 187/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8145 - mae: 1.5212 - val_loss: 9.1027 - val_mae: 1.7249
# Epoch 188/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.7772 - mae: 1.4914 - val_loss: 8.9286 - val_mae: 1.7713
# Epoch 189/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8267 - mae: 1.5228 - val_loss: 8.9789 - val_mae: 1.7106
# Epoch 190/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8585 - mae: 1.5270 - val_loss: 9.8544 - val_mae: 1.7852
# Epoch 191/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9272 - mae: 1.5304 - val_loss: 9.1123 - val_mae: 1.6778
# Epoch 192/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.8063 - mae: 1.5185 - val_loss: 9.2612 - val_mae: 1.7802
# Epoch 193/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6769 - mae: 1.4739 - val_loss: 9.0008 - val_mae: 1.7018
# Epoch 194/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8022 - mae: 1.4952 - val_loss: 9.3045 - val_mae: 1.7277
# Epoch 195/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6245 - mae: 1.4681 - val_loss: 9.2557 - val_mae: 1.6972
# Epoch 196/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6709 - mae: 1.4827 - val_loss: 9.1711 - val_mae: 1.7123
# Epoch 197/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.7782 - mae: 1.4889 - val_loss: 9.7824 - val_mae: 1.7472
# Epoch 198/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.6808 - mae: 1.4884 - val_loss: 9.6917 - val_mae: 1.6654
# Epoch 199/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.5850 - mae: 1.4577 - val_loss: 9.6852 - val_mae: 1.6846
# Epoch 200/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.6549 - mae: 1.4823 - val_loss: 9.7953 - val_mae: 1.7332
# Epoch 201/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.7419 - mae: 1.4919 - val_loss: 9.8925 - val_mae: 1.7156
# Epoch 202/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.7151 - mae: 1.4880 - val_loss: 9.9881 - val_mae: 1.6934
# Epoch 203/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6738 - mae: 1.4705 - val_loss: 9.8144 - val_mae: 1.7310
# Epoch 204/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6924 - mae: 1.4810 - val_loss: 10.3706 - val_mae: 1.7506
# Epoch 205/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6500 - mae: 1.4675 - val_loss: 10.3305 - val_mae: 1.7649
# Epoch 206/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.6016 - mae: 1.4590 - val_loss: 10.6884 - val_mae: 1.7152
# Epoch 207/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6330 - mae: 1.4729 - val_loss: 9.9288 - val_mae: 1.7043
# Epoch 208/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6691 - mae: 1.4728 - val_loss: 10.3041 - val_mae: 1.6961
# Epoch 209/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8345 - mae: 1.5173 - val_loss: 9.6541 - val_mae: 1.6859
# Epoch 210/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.6748 - mae: 1.4668 - val_loss: 10.3486 - val_mae: 1.7119
# Epoch 211/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.5623 - mae: 1.4546 - val_loss: 10.0108 - val_mae: 1.7319
# Epoch 212/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.7668 - mae: 1.4933 - val_loss: 10.0843 - val_mae: 1.7112
# Epoch 213/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.7543 - mae: 1.4825 - val_loss: 10.0297 - val_mae: 1.7618
# Epoch 214/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.5332 - mae: 1.4627 - val_loss: 10.4990 - val_mae: 1.6633
# Epoch 215/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.4805 - mae: 1.4286 - val_loss: 10.3317 - val_mae: 1.7525
# Epoch 216/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.9523 - mae: 1.5229 - val_loss: 10.4633 - val_mae: 1.6765
# Epoch 217/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.7358 - mae: 1.4884 - val_loss: 9.5589 - val_mae: 1.6921
# Epoch 218/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.7035 - mae: 1.4685 - val_loss: 10.1828 - val_mae: 1.7219
# Epoch 219/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.6404 - mae: 1.4734 - val_loss: 9.6655 - val_mae: 1.6722
# Epoch 220/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.6521 - mae: 1.4860 - val_loss: 9.8573 - val_mae: 1.6555
# Epoch 221/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.4204 - mae: 1.4126 - val_loss: 9.8815 - val_mae: 1.6600
# Epoch 222/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.5689 - mae: 1.4542 - val_loss: 10.0420 - val_mae: 1.7679
# Epoch 223/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.8509 - mae: 1.5058 - val_loss: 11.7042 - val_mae: 1.7751
# Epoch 224/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 4.4731 - mae: 1.6075 - val_loss: 11.3618 - val_mae: 1.9681
# Epoch 225/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.1906 - mae: 1.5510 - val_loss: 11.4546 - val_mae: 1.6978
# Epoch 226/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.2123 - mae: 1.5610 - val_loss: 10.9947 - val_mae: 1.8355
# Epoch 227/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.5401 - mae: 1.4502 - val_loss: 10.7615 - val_mae: 1.6845
# Epoch 228/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.8809 - mae: 1.5190 - val_loss: 10.7310 - val_mae: 1.8854
# Epoch 229/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 3.6350 - mae: 1.4615 - val_loss: 10.5705 - val_mae: 1.7204
# Epoch 230/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.5178 - mae: 1.4525 - val_loss: 10.3968 - val_mae: 1.7174
# Epoch 231/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.5911 - mae: 1.4555 - val_loss: 10.4739 - val_mae: 1.6661
# Epoch 232/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.3512 - mae: 1.3935 - val_loss: 10.4214 - val_mae: 1.6624
# Epoch 233/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.4475 - mae: 1.4140 - val_loss: 11.4485 - val_mae: 1.7194
# Epoch 234/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.4298 - mae: 1.4178 - val_loss: 10.7546 - val_mae: 1.6610
# Epoch 235/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.3094 - mae: 1.3891 - val_loss: 10.9891 - val_mae: 1.6641
# Epoch 236/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4369 - mae: 1.4245 - val_loss: 10.9995 - val_mae: 1.7757
# Epoch 237/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.4405 - mae: 1.4232 - val_loss: 10.9102 - val_mae: 1.6404
# Epoch 238/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.3054 - mae: 1.3881 - val_loss: 10.9564 - val_mae: 1.7593
# Epoch 239/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4827 - mae: 1.4311 - val_loss: 11.2128 - val_mae: 1.8130
# Epoch 240/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.5663 - mae: 1.4572 - val_loss: 10.8267 - val_mae: 1.6663
# Epoch 241/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.4844 - mae: 1.4451 - val_loss: 10.8792 - val_mae: 1.6227
# Epoch 242/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3794 - mae: 1.4070 - val_loss: 10.7478 - val_mae: 1.6717
# Epoch 243/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3559 - mae: 1.4115 - val_loss: 10.9222 - val_mae: 1.6185
# Epoch 244/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3960 - mae: 1.4123 - val_loss: 11.5286 - val_mae: 1.7098
# Epoch 245/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.5146 - mae: 1.4478 - val_loss: 10.7199 - val_mae: 1.6130
# Epoch 246/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3721 - mae: 1.4096 - val_loss: 11.0774 - val_mae: 1.6502
# Epoch 247/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2390 - mae: 1.3757 - val_loss: 11.0891 - val_mae: 1.6376
# Epoch 248/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1579 - mae: 1.3517 - val_loss: 11.6301 - val_mae: 1.6574
# Epoch 249/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3049 - mae: 1.3909 - val_loss: 10.8716 - val_mae: 1.7401
# Epoch 250/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.9055 - mae: 1.5067 - val_loss: 12.4970 - val_mae: 1.8345
# Epoch 251/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.0284 - mae: 1.5313 - val_loss: 11.4550 - val_mae: 1.7440
# Epoch 252/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.5862 - mae: 1.6261 - val_loss: 12.2102 - val_mae: 1.7019
# Epoch 253/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.1522 - mae: 1.5560 - val_loss: 11.8461 - val_mae: 1.7335
# Epoch 254/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.3535 - mae: 1.4100 - val_loss: 12.2181 - val_mae: 1.8778
# Epoch 255/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2537 - mae: 1.3892 - val_loss: 11.1254 - val_mae: 1.6798
# Epoch 256/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4416 - mae: 1.4220 - val_loss: 11.0596 - val_mae: 1.6527
# Epoch 257/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3116 - mae: 1.3946 - val_loss: 11.4131 - val_mae: 1.6620
# Epoch 258/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2244 - mae: 1.3763 - val_loss: 10.8351 - val_mae: 1.6835
# Epoch 259/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.5848 - mae: 1.4585 - val_loss: 12.6610 - val_mae: 2.0972
# Epoch 260/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.6946 - mae: 1.4877 - val_loss: 11.1615 - val_mae: 1.6331
# Epoch 261/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3056 - mae: 1.3774 - val_loss: 11.2115 - val_mae: 1.6456
# Epoch 262/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.4745 - mae: 1.4404 - val_loss: 11.0903 - val_mae: 1.7429
# Epoch 263/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.2475 - mae: 1.3728 - val_loss: 11.4823 - val_mae: 1.7183
# Epoch 264/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1543 - mae: 1.3539 - val_loss: 11.6883 - val_mae: 1.6893
# Epoch 265/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3663 - mae: 1.4170 - val_loss: 11.5053 - val_mae: 1.6847
# Epoch 266/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.7193 - mae: 1.4778 - val_loss: 13.0138 - val_mae: 1.8983
# Epoch 267/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.3259 - mae: 1.3899 - val_loss: 12.0834 - val_mae: 1.6246
# Epoch 268/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2234 - mae: 1.3734 - val_loss: 11.8085 - val_mae: 1.6560
# Epoch 269/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1328 - mae: 1.3517 - val_loss: 12.2570 - val_mae: 1.6797
# Epoch 270/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.2561 - mae: 1.3835 - val_loss: 11.2534 - val_mae: 1.7911
# Epoch 271/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1025 - mae: 1.3386 - val_loss: 11.7084 - val_mae: 1.6503
# Epoch 272/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2897 - mae: 1.3871 - val_loss: 12.0345 - val_mae: 1.8320
# Epoch 273/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3631 - mae: 1.4119 - val_loss: 11.9392 - val_mae: 1.6823
# Epoch 274/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1725 - mae: 1.3584 - val_loss: 11.5408 - val_mae: 1.6636
# Epoch 275/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1207 - mae: 1.3373 - val_loss: 11.8544 - val_mae: 1.6710
# Epoch 276/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2855 - mae: 1.3825 - val_loss: 10.9878 - val_mae: 1.6691
# Epoch 277/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.0886 - mae: 1.3293 - val_loss: 12.8055 - val_mae: 1.9027
# Epoch 278/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3960 - mae: 1.4172 - val_loss: 11.0169 - val_mae: 1.6308
# Epoch 279/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1735 - mae: 1.3629 - val_loss: 10.9489 - val_mae: 1.6317
# Epoch 280/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1634 - mae: 1.3672 - val_loss: 11.7012 - val_mae: 1.7045
# Epoch 281/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1711 - mae: 1.3687 - val_loss: 11.1001 - val_mae: 1.6179
# Epoch 282/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3545 - mae: 1.4056 - val_loss: 11.3961 - val_mae: 1.6253
# Epoch 283/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 4.1239 - mae: 1.5274 - val_loss: 12.5222 - val_mae: 1.8296
# Epoch 284/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.4027 - mae: 1.4211 - val_loss: 11.1640 - val_mae: 1.6040
# Epoch 285/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6227 - mae: 1.4638 - val_loss: 11.4774 - val_mae: 1.6009
# Epoch 286/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2957 - mae: 1.3853 - val_loss: 11.4826 - val_mae: 1.6250
# Epoch 287/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0777 - mae: 1.3301 - val_loss: 11.1825 - val_mae: 1.5928
# Epoch 288/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1320 - mae: 1.3481 - val_loss: 11.3603 - val_mae: 1.6354
# Epoch 289/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1016 - mae: 1.3523 - val_loss: 11.4606 - val_mae: 1.6801
# Epoch 290/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1181 - mae: 1.3383 - val_loss: 11.5704 - val_mae: 1.6814
# Epoch 291/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.9711 - mae: 1.3156 - val_loss: 12.0060 - val_mae: 1.6271
# Epoch 292/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6169 - mae: 1.4181 - val_loss: 12.0177 - val_mae: 1.8621
# Epoch 293/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3788 - mae: 1.3982 - val_loss: 12.3500 - val_mae: 1.8240
# Epoch 294/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 4.0080 - mae: 1.5098 - val_loss: 12.0618 - val_mae: 1.6746
# Epoch 295/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2368 - mae: 1.3676 - val_loss: 12.1796 - val_mae: 1.7218
# Epoch 296/1000
# 20/20 [==============================] - 0s 6ms/step - loss: 3.2143 - mae: 1.3636 - val_loss: 11.0748 - val_mae: 1.6540
# Epoch 297/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1711 - mae: 1.3502 - val_loss: 11.4835 - val_mae: 1.6295
# Epoch 298/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2456 - mae: 1.3827 - val_loss: 12.0984 - val_mae: 1.6817
# Epoch 299/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2284 - mae: 1.3702 - val_loss: 11.7787 - val_mae: 1.7136
# Epoch 300/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6323 - mae: 1.4664 - val_loss: 10.9467 - val_mae: 1.6508
# Epoch 301/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1834 - mae: 1.3795 - val_loss: 11.0673 - val_mae: 1.6154
# Epoch 302/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1596 - mae: 1.3514 - val_loss: 10.8990 - val_mae: 1.5949
# Epoch 303/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1806 - mae: 1.3419 - val_loss: 11.6120 - val_mae: 1.6350
# Epoch 304/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.3450 - mae: 1.4033 - val_loss: 11.2492 - val_mae: 1.5931
# Epoch 305/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.9865 - mae: 1.3161 - val_loss: 11.1806 - val_mae: 1.7660
# Epoch 306/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.4355 - mae: 1.4262 - val_loss: 11.5580 - val_mae: 1.7704
# Epoch 307/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.4367 - mae: 1.4158 - val_loss: 11.2034 - val_mae: 1.6333
# Epoch 308/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2739 - mae: 1.3817 - val_loss: 12.0554 - val_mae: 1.6876
# Epoch 309/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.9596 - mae: 1.3094 - val_loss: 11.1454 - val_mae: 1.6197
# Epoch 310/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0260 - mae: 1.3336 - val_loss: 11.5038 - val_mae: 1.6346
# Epoch 311/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2558 - mae: 1.3710 - val_loss: 11.0341 - val_mae: 1.6055
# Epoch 312/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3413 - mae: 1.3987 - val_loss: 10.9852 - val_mae: 1.6040
# Epoch 313/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 3.0300 - mae: 1.3201 - val_loss: 11.6632 - val_mae: 1.6169
# Epoch 314/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1555 - mae: 1.3590 - val_loss: 13.2197 - val_mae: 1.7018
# Epoch 315/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6985 - mae: 1.4787 - val_loss: 11.6613 - val_mae: 1.6391
# Epoch 316/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 3.1063 - mae: 1.3493 - val_loss: 11.5614 - val_mae: 1.6630
# Epoch 317/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.0674 - mae: 1.3397 - val_loss: 10.9637 - val_mae: 1.5793
# Epoch 318/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0067 - mae: 1.3173 - val_loss: 11.3221 - val_mae: 1.5848
# Epoch 319/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 2.9669 - mae: 1.3123 - val_loss: 12.0742 - val_mae: 1.6074
# Epoch 320/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0059 - mae: 1.3207 - val_loss: 12.2113 - val_mae: 1.7358
# Epoch 321/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1997 - mae: 1.3592 - val_loss: 11.5714 - val_mae: 1.6859
# Epoch 322/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.8419 - mae: 1.4725 - val_loss: 11.6899 - val_mae: 1.7703
# Epoch 323/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0715 - mae: 1.3464 - val_loss: 10.8188 - val_mae: 1.6304
# Epoch 324/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1393 - mae: 1.3591 - val_loss: 11.6957 - val_mae: 1.7791
# Epoch 325/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.6980 - mae: 1.4825 - val_loss: 11.7224 - val_mae: 1.6808
# Epoch 326/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.1681 - mae: 1.3619 - val_loss: 11.5992 - val_mae: 1.7523
# Epoch 327/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2607 - mae: 1.3541 - val_loss: 10.9420 - val_mae: 1.6307
# Epoch 328/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.4497 - mae: 1.4079 - val_loss: 10.6610 - val_mae: 1.6587
# Epoch 329/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2538 - mae: 1.3761 - val_loss: 11.6991 - val_mae: 1.6730
# Epoch 330/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2087 - mae: 1.3597 - val_loss: 11.6333 - val_mae: 1.6410
# Epoch 331/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1425 - mae: 1.3531 - val_loss: 11.3406 - val_mae: 1.6906
# Epoch 332/1000
# 20/20 [==============================] - 0s 5ms/step - loss: 2.9804 - mae: 1.3228 - val_loss: 12.4090 - val_mae: 1.6089
# Epoch 333/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3890 - mae: 1.3983 - val_loss: 11.0918 - val_mae: 1.7150
# Epoch 334/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0719 - mae: 1.3399 - val_loss: 10.6325 - val_mae: 1.6851
# Epoch 335/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0704 - mae: 1.3394 - val_loss: 11.1825 - val_mae: 1.7947
# Epoch 336/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2062 - mae: 1.3597 - val_loss: 11.1111 - val_mae: 1.6283
# Epoch 337/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 2.9501 - mae: 1.3115 - val_loss: 11.2427 - val_mae: 1.6341
# Epoch 338/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2176 - mae: 1.3517 - val_loss: 11.1761 - val_mae: 1.5957
# Epoch 339/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.9334 - mae: 1.3084 - val_loss: 11.1160 - val_mae: 1.6818
# Epoch 340/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0423 - mae: 1.3343 - val_loss: 11.8234 - val_mae: 1.6163
# Epoch 341/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.8898 - mae: 1.2984 - val_loss: 11.6674 - val_mae: 1.6565
# Epoch 342/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.8610 - mae: 1.2830 - val_loss: 11.0954 - val_mae: 1.6475
# Epoch 343/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.0540 - mae: 1.3359 - val_loss: 11.2715 - val_mae: 1.6602
# Epoch 344/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 2.9962 - mae: 1.3018 - val_loss: 11.3998 - val_mae: 1.5881
# Epoch 345/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.2589 - mae: 1.3651 - val_loss: 11.2126 - val_mae: 1.6448
# Epoch 346/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 3.6633 - mae: 1.4399 - val_loss: 11.7176 - val_mae: 1.6650
# Epoch 347/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.6832 - mae: 1.4611 - val_loss: 11.2291 - val_mae: 1.6003
# Epoch 348/1000
# 20/20 [==============================] - 0s 7ms/step - loss: 3.8143 - mae: 1.4883 - val_loss: 12.2493 - val_mae: 1.6668
# Epoch 349/1000
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3259 - mae: 1.3911 - val_loss: 11.8710 - val_mae: 1.5667
# Epoch 350/1000
# ...
# 20/20 [==============================] - 0s 13ms/step - loss: 2.4500 - mae: 1.1556 - val_loss: 13.7143 - val_mae: 1.5492
# Epoch 890/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5490 - mae: 1.1731 - val_loss: 14.6046 - val_mae: 1.5893
# Epoch 891/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 3.0654 - mae: 1.2946 - val_loss: 14.2613 - val_mae: 1.4879
# Epoch 892/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3590 - mae: 1.1249 - val_loss: 14.4429 - val_mae: 1.5512
# Epoch 893/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5337 - mae: 1.1854 - val_loss: 14.3291 - val_mae: 1.5836
# Epoch 894/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.4058 - mae: 1.1226 - val_loss: 13.4212 - val_mae: 1.4575
# Epoch 895/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3547 - mae: 1.1294 - val_loss: 13.7336 - val_mae: 1.3925
# Epoch 896/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1405 - mae: 1.0794 - val_loss: 15.3773 - val_mae: 1.5279
# Epoch 897/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3629 - mae: 1.1291 - val_loss: 14.0784 - val_mae: 1.5074
# Epoch 898/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4590 - mae: 1.1512 - val_loss: 13.8121 - val_mae: 1.4446
# Epoch 899/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.4091 - mae: 1.1415 - val_loss: 14.5381 - val_mae: 1.4984
# Epoch 900/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4958 - mae: 1.1452 - val_loss: 14.1807 - val_mae: 1.5804
# Epoch 901/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3653 - mae: 1.1545 - val_loss: 14.6349 - val_mae: 1.5463
# Epoch 902/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2789 - mae: 1.1004 - val_loss: 13.2724 - val_mae: 1.3795
# Epoch 903/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1928 - mae: 1.0754 - val_loss: 12.8947 - val_mae: 1.4944
# Epoch 904/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2508 - mae: 1.1053 - val_loss: 14.3268 - val_mae: 1.4377
# Epoch 905/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3511 - mae: 1.1190 - val_loss: 15.0208 - val_mae: 1.8580
# Epoch 906/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 3.4871 - mae: 1.3563 - val_loss: 14.5574 - val_mae: 1.6603
# Epoch 907/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 4.5958 - mae: 1.5375 - val_loss: 15.9856 - val_mae: 1.5985
# Epoch 908/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8166 - mae: 1.2089 - val_loss: 13.5587 - val_mae: 1.5502
# Epoch 909/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.4734 - mae: 1.1634 - val_loss: 13.8151 - val_mae: 1.5054
# Epoch 910/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3462 - mae: 1.1232 - val_loss: 12.7381 - val_mae: 1.4456
# Epoch 911/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.2071 - mae: 1.1014 - val_loss: 12.5126 - val_mae: 1.4205
# Epoch 912/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2805 - mae: 1.0976 - val_loss: 12.9792 - val_mae: 1.4925
# Epoch 913/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4897 - mae: 1.1702 - val_loss: 14.3419 - val_mae: 1.4735
# Epoch 914/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 3.2612 - mae: 1.3358 - val_loss: 12.6983 - val_mae: 1.4672
# Epoch 915/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.4513 - mae: 1.1447 - val_loss: 13.8361 - val_mae: 1.6141
# Epoch 916/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4047 - mae: 1.1680 - val_loss: 13.4608 - val_mae: 1.4763
# Epoch 917/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6205 - mae: 1.2138 - val_loss: 14.0130 - val_mae: 1.4094
# Epoch 918/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0940 - mae: 1.0427 - val_loss: 13.1601 - val_mae: 1.3923
# Epoch 919/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.1811 - mae: 1.0867 - val_loss: 12.5790 - val_mae: 1.4222
# Epoch 920/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3379 - mae: 1.1264 - val_loss: 13.1194 - val_mae: 1.4341
# Epoch 921/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3749 - mae: 1.1271 - val_loss: 12.8951 - val_mae: 1.4518
# Epoch 922/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1269 - mae: 1.0715 - val_loss: 13.7014 - val_mae: 1.4928
# Epoch 923/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.3635 - mae: 1.1184 - val_loss: 13.2498 - val_mae: 1.5285
# Epoch 924/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 2.1608 - mae: 1.0692 - val_loss: 13.4041 - val_mae: 1.4115
# Epoch 925/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.0726 - mae: 1.0526 - val_loss: 13.0813 - val_mae: 1.3651
# Epoch 926/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3037 - mae: 1.1145 - val_loss: 13.5114 - val_mae: 1.4647
# Epoch 927/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1474 - mae: 1.0594 - val_loss: 13.7379 - val_mae: 1.5180
# Epoch 928/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2974 - mae: 1.1024 - val_loss: 13.0392 - val_mae: 1.4928
# Epoch 929/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.3662 - mae: 1.1088 - val_loss: 14.0776 - val_mae: 1.4485
# Epoch 930/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2761 - mae: 1.0971 - val_loss: 13.7968 - val_mae: 1.4436
# Epoch 931/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.2409 - mae: 1.0827 - val_loss: 13.5657 - val_mae: 1.6817
# Epoch 932/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2268 - mae: 1.0878 - val_loss: 13.3877 - val_mae: 1.4390
# Epoch 933/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.0263 - mae: 1.0383 - val_loss: 13.2592 - val_mae: 1.4436
# Epoch 934/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.2937 - mae: 1.1005 - val_loss: 12.6678 - val_mae: 1.4445
# Epoch 935/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5104 - mae: 1.1525 - val_loss: 14.9594 - val_mae: 1.7852
# Epoch 936/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.7519 - mae: 1.2277 - val_loss: 12.9881 - val_mae: 1.4463
# Epoch 937/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2740 - mae: 1.1245 - val_loss: 13.1900 - val_mae: 1.5125
# Epoch 938/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.2855 - mae: 1.1197 - val_loss: 12.8687 - val_mae: 1.4675
# Epoch 939/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 2.3863 - mae: 1.1582 - val_loss: 13.0593 - val_mae: 1.4349
# Epoch 940/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1782 - mae: 1.0914 - val_loss: 13.1940 - val_mae: 1.4223
# Epoch 941/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 2.1580 - mae: 1.0695 - val_loss: 13.6207 - val_mae: 1.3925
# Epoch 942/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2583 - mae: 1.1176 - val_loss: 13.2057 - val_mae: 1.4740
# Epoch 943/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 2.2660 - mae: 1.1193 - val_loss: 13.7048 - val_mae: 1.5092
# Epoch 944/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4466 - mae: 1.1259 - val_loss: 13.1833 - val_mae: 1.5046
# Epoch 945/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 2.2091 - mae: 1.0830 - val_loss: 12.7429 - val_mae: 1.3635
# Epoch 946/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.1843 - mae: 1.0939 - val_loss: 13.0822 - val_mae: 1.3800
# Epoch 947/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 2.1067 - mae: 1.0612 - val_loss: 12.9655 - val_mae: 1.4496
# Epoch 948/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1824 - mae: 1.0975 - val_loss: 13.6121 - val_mae: 1.3861
# Epoch 949/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4584 - mae: 1.1418 - val_loss: 13.5617 - val_mae: 1.4058
# Epoch 950/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.2547 - mae: 1.0951 - val_loss: 12.8985 - val_mae: 1.4512
# Epoch 951/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3083 - mae: 1.1072 - val_loss: 13.6278 - val_mae: 1.4936
# Epoch 952/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0722 - mae: 1.0526 - val_loss: 13.3210 - val_mae: 1.3691
# Epoch 953/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2276 - mae: 1.1051 - val_loss: 13.4311 - val_mae: 1.4875
# Epoch 954/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.5437 - mae: 1.1823 - val_loss: 13.5022 - val_mae: 1.4942
# Epoch 955/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3670 - mae: 1.1101 - val_loss: 13.5099 - val_mae: 1.5329
# Epoch 956/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 2.2959 - mae: 1.1204 - val_loss: 13.5093 - val_mae: 1.4491
# Epoch 957/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1587 - mae: 1.0716 - val_loss: 13.2984 - val_mae: 1.3783
# Epoch 958/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1380 - mae: 1.0736 - val_loss: 13.0417 - val_mae: 1.5479
# Epoch 959/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2555 - mae: 1.1059 - val_loss: 13.5210 - val_mae: 1.4900
# Epoch 960/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1527 - mae: 1.0573 - val_loss: 13.2448 - val_mae: 1.3873
# Epoch 961/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.0362 - mae: 1.0372 - val_loss: 13.3537 - val_mae: 1.5458
# Epoch 962/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3162 - mae: 1.1127 - val_loss: 12.6002 - val_mae: 1.4130
# Epoch 963/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.6325 - mae: 1.1851 - val_loss: 14.0437 - val_mae: 1.5089
# Epoch 964/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4148 - mae: 1.1240 - val_loss: 14.1053 - val_mae: 1.5154
# Epoch 965/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0735 - mae: 1.0450 - val_loss: 13.2030 - val_mae: 1.4049
# Epoch 966/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2013 - mae: 1.0694 - val_loss: 13.9394 - val_mae: 1.5368
# Epoch 967/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.1359 - mae: 1.0601 - val_loss: 13.9137 - val_mae: 1.3959
# Epoch 968/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 2.3939 - mae: 1.1143 - val_loss: 13.5129 - val_mae: 1.3751
# Epoch 969/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0447 - mae: 1.0548 - val_loss: 12.9845 - val_mae: 1.3844
# Epoch 970/1000
# 20/20 [==============================] - 0s 11ms/step - loss: 2.2457 - mae: 1.0806 - val_loss: 12.6255 - val_mae: 1.4432
# Epoch 971/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.3417 - mae: 1.1215 - val_loss: 12.9805 - val_mae: 1.3527
# Epoch 972/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4841 - mae: 1.1261 - val_loss: 14.3193 - val_mae: 1.6014
# Epoch 973/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 2.5442 - mae: 1.1749 - val_loss: 13.4044 - val_mae: 1.4368
# Epoch 974/1000
# 20/20 [==============================] - 0s 14ms/step - loss: 2.7220 - mae: 1.1489 - val_loss: 16.1835 - val_mae: 1.9221
# Epoch 975/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 4.2514 - mae: 1.5459 - val_loss: 14.1839 - val_mae: 1.8926
# Epoch 976/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.9313 - mae: 1.2628 - val_loss: 13.9740 - val_mae: 1.5009
# Epoch 977/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1778 - mae: 1.0775 - val_loss: 13.5453 - val_mae: 1.3885
# Epoch 978/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3518 - mae: 1.1161 - val_loss: 13.0584 - val_mae: 1.3565
# Epoch 979/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3361 - mae: 1.1186 - val_loss: 14.2324 - val_mae: 1.7206
# Epoch 980/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 3.8786 - mae: 1.5010 - val_loss: 13.9676 - val_mae: 1.5085
# Epoch 981/1000
# 20/20 [==============================] - 0s 15ms/step - loss: 2.3129 - mae: 1.1167 - val_loss: 13.7726 - val_mae: 1.4276
# Epoch 982/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1466 - mae: 1.0574 - val_loss: 13.1304 - val_mae: 1.4934
# Epoch 983/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6761 - mae: 1.1694 - val_loss: 13.2744 - val_mae: 1.5049
# Epoch 984/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.2544 - mae: 1.0980 - val_loss: 12.6301 - val_mae: 1.4350
# Epoch 985/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1779 - mae: 1.0748 - val_loss: 13.1112 - val_mae: 1.4450
# Epoch 986/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1905 - mae: 1.0599 - val_loss: 12.9011 - val_mae: 1.4460
# Epoch 987/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.2893 - mae: 1.0858 - val_loss: 13.6897 - val_mae: 1.4531
# Epoch 988/1000
# 20/20 [==============================] - 0s 13ms/step - loss: 2.3775 - mae: 1.1363 - val_loss: 13.5074 - val_mae: 1.4190
# Epoch 989/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5786 - mae: 1.1650 - val_loss: 13.9212 - val_mae: 1.4283
# Epoch 990/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.7996 - mae: 1.2484 - val_loss: 12.9955 - val_mae: 1.4326
# Epoch 991/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2114 - mae: 1.0897 - val_loss: 12.7630 - val_mae: 1.4286
# Epoch 992/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1263 - mae: 1.0898 - val_loss: 13.5892 - val_mae: 1.4741
# Epoch 993/1000
# 20/20 [==============================] - 0s 16ms/step - loss: 2.0493 - mae: 1.0358 - val_loss: 13.1759 - val_mae: 1.4436
# Epoch 994/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3522 - mae: 1.0967 - val_loss: 13.8251 - val_mae: 1.4827
# Epoch 995/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2685 - mae: 1.1085 - val_loss: 13.0869 - val_mae: 1.3764
# Epoch 996/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1107 - mae: 1.0699 - val_loss: 13.2683 - val_mae: 1.3459
# Epoch 997/1000
# 20/20 [==============================] - 0s 12ms/step - loss: 2.1972 - mae: 1.0872 - val_loss: 13.1825 - val_mae: 1.4856
# Epoch 998/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2217 - mae: 1.1038 - val_loss: 12.8547 - val_mae: 1.4852
# Epoch 999/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2548 - mae: 1.0794 - val_loss: 13.4177 - val_mae: 1.3794
# Epoch 1000/1000
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2883 - mae: 1.1205 - val_loss: 12.8476 - val_mae: 1.4448
# 1/1 [==============================] - 0s 245ms/step
# Predicted values are:  [[ 82.97898  143.56291  183.02678 ]
#  [ 79.271286 140.80559  184.55792 ]
#  [ 87.73521  137.5581   182.47192 ]
#  [ 86.357796 136.77574  183.24791 ]
#  [ 79.29256  143.03372  184.66478 ]]
# Real values are:       Substrate Thickness  Patch Length  Patch Width
# 832                   83           144          183
# 569                   80           141          187
# 208                   88           138          180
# 36                    86           136          183
# 759                   80           143          186
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2632 - mae: 1.0870
# Mean squared error from neural net:  2.263195753097534
# Mean absolute error from neural net:  1.0869712829589844

# %%
from __future__ import absolute_import, division, print_function

import pathlib
import pandas
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)

def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation=tf.nn.relu, input_shape=[3]),
        layers.Dense(64, activation=tf.nn.relu),
        layers.Dense(3)
    ])

    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse', optimizer=optimizer, metrics=['mae', 'mse'])

    return model

model = build_model()
# Out:
# 2.12.0

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 64)                256
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dense_13 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 4,611
# Trainable params: 4,611
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = model.predict(X_test_scaled[:5])
print("Predicted values are: \n", predictions)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Predicted values are:
#  [[-0.09742586  0.22095972  0.09305312]
#  [-0.08201828  0.19252391 -0.03280456]
#  [-0.057517    0.27284282  0.01640146]
#  [-0.07915493  0.15089957  0.06450693]
#  [-0.05936565  0.22221646 -0.07363758]]

# %%
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end ='')

EPOCHS = 20

history = model.fit(
    X_train_scaled, y_train, validation_split=0.2, epochs=EPOCHS, verbose=0, callbacks=[PrintDot()]
)
# Out:
# ....................

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

lr_model = linear_model.LinearRegression()
lr_model.fit(X_train_scaled, y_train)
y_pred_lr = lr_model.predict(X_test_scaled)
mse_lr = mean_squared_error(y_test, y_pred_lr)
mae_lr = mean_absolute_error(y_test, y_pred_lr)
print('Mean squared error from linear regression: ', mse_lr)
print('Mean absolute error from linear regression: ', mae_lr)
# Out:
# Mean squared error from linear regression:  33.16543519504176
# Mean absolute error from linear regression:  2.232313675273073

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)

X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 200, random_state=20)
model.fit(X_train_scaled, y_train)


y_pred_RF = model.predict(X_test_scaled)

mse_RF = mean_squared_error(y_test, y_pred_RF)
mae_RF = mean_absolute_error(y_test, y_pred_RF)
print('Mean squared error using Random Forest: ', mse_RF)
print('Mean absolute error Using Random Forest: ', mae_RF)

predictions = model.predict(X_test_scaled[:5])
print("Predicted values are: \n", predictions)
print("Real values are: \n", y_test[:5])
# Out:
# Mean squared error using Random Forest:  27.09080409238113
# Mean absolute error Using Random Forest:  1.7862263760833341
# Predicted values are:
#  [[  0.6717025 -22.87895     9.046983 ]
#  [  0.685036  -32.12935     8.9632265]
#  [  0.658072  -19.387355    9.475701 ]
#  [  0.681958  -45.645305    8.812678 ]
#  [  0.6720535 -29.75395     9.1482085]]
# Real values are:
#       Frequency  Return Loss (s11)    Gain
# 741     0.6724            -22.928  9.0172
# 404     0.6805            -35.134  8.9444
# 530     0.6544            -18.841  9.6034
# 347     0.6877            -29.185  8.7434
# 471     0.6733            -30.347  9.1131

# %%
import numpy as np
import matplotlib.pyplot as plt
 
 
def per(x,y):
    num = 1
    while x != y:
        if x > y:
            x = x-(1/num)
        else:
            x = x+(1/num)
        num += 1
    return num
 
 
y1 = 2 #number with footprint
 
if int(input('Zoom search = 1, Normal search = 0:')) == 1:
    peak = float(input('Enter peak:'))
    search = float(input('Enter Search area:'))
    leng = int(input('Enter sample amount:'))
    l1 = np.zeros(leng)
    x1 = np.linspace(peak-(search*0.5),peak+(search*0.5), leng)
else:
    leng= int(input('Enter sample amount:'))
    x1 = np.linspace(0,2,leng)
    l1 = np.zeros(leng)
 
for i in range(leng):
    l1[i] = per(x1[i],y1)
l2 = l1
 
 
#max checker
for n in range(16):
    print(x1[np.argmax(l2)], np.max(l2))
    l2[np.argmax(l1)] = y1
 
plt.plot(x1,l1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 18
#      13     return num
#      16 y1 = 2 #number with footprint
# ---> 18 if int(input('Zoom search = 1, Normal search = 0:')) == 1:
#      19     peak = float(input('Enter peak:'))
#      20     search = float(input('Enter Search area:'))
#
# ValueError: invalid literal for int() with base 10: ''
